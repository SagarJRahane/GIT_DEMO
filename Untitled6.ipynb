# %%
# !pip install webdriver-manager
# Out:
# Collecting webdriver-manager
#   Downloading webdriver_manager-3.8.5-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: tqdm in c:\users\shree\appdata\local\programs\python\python310\lib\site-packages (from webdriver-manager) (4.63.1)
# Requirement already satisfied: requests in c:\users\shree\appdata\local\programs\python\python310\lib\site-packages (from webdriver-manager) (2.27.1)
# Collecting python-dotenv
#   Downloading python_dotenv-0.21.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: packaging in c:\users\shree\appdata\local\programs\python\python310\lib\site-packages (from webdriver-manager) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\shree\appdata\local\programs\python\python310\lib\site-packages (from packaging->webdriver-manager) (3.0.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shree\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shree\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\shree\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\shree\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (2.0.12)
# Requirement already satisfied: colorama in c:\users\shree\appdata\local\programs\python\python310\lib\site-packages (from tqdm->webdriver-manager) (0.4.4)
# Installing collected packages: python-dotenv, webdriver-manager
# Successfully installed python-dotenv-0.21.0 webdriver-manager-3.8.5

# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://www.nseindia.com/")
html=driver.page_source
soup = BeautifulSoup(html,'html.parser')
# Out:
# [WDM] - Downloading: 100%|██████████████████████████████████████████████████████████| 6.58M/6.58M [00:01<00:00, 6.88MB/s]
# C:\Users\Shree\AppData\Local\Temp\ipykernel_13464\1391000446.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
print("Title of the website is : ") 
for title in soup.find_all('title'): 
    print(title.get_text())
# Out:
# Title of the website is :
# NSE - National Stock Exchange of India Ltd: Live Share/Stock Market News & Updates, Quotes- Nseindia.com

# %%
para=soup.select('p')
para
# Out:
# [<p class="redTxt">Debt Market is Closed</p>,
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>,
#  <p class="redTxt" id="capMarStat">Normal Market has Closed</p>,
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>,
#  <p class="redTxt">Currency Market is Closed</p>,
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>,
#  <p class="greenTxt">Commodity Market is Open</p>,
#  <p class="next_date">Current
#                                              Trading Date - 08-Dec-2022</p>,
#  <p class="redTxt">Debt Market is Closed</p>,
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>,
#  <p class="redTxt" id="">Normal Market has Closed</p>,
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>,
#  <p class="redTxt">Currency Market is Closed</p>,
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>,
#  <p class="greenTxt">Commodity Market is Open</p>,
#  <p class="next_date">Current
#                                              Trading Date - 08-Dec-2022</p>,
#  <p class="redTxt">Debt Market is Closed</p>,
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>,
#  <p>Find everything about the leading stock exchange of India</p>,
#  <p>Check NSE's group of the companies</p>,
#  <p>Browse a comprehensive and innovative product and service offerings by NSE</p>,
#  <p>Live Analysis of top gainers/losers, most active securities/contracts, price band hitters, overview of the market.</p>,
#  <p>View Option chain for the exchange</p>,
#  <p>Screen stocks based on key fundamentals with the NSE Stock Screener to make your investing a more process-driven.</p>,
#  <p>Investor education on how to invest safely and protect your investments. </p>,
#  <p>Browse NSE products under Cash, derivatives, currency derivatives etc.</p>,
#  <p>File and Track your Complaint online.</p>,
#  <p>Important information, reference material and latest announcements for corporates</p>,
#  <p>Status of compliance's under various Regulatory requirements</p>,
#  <p>Login for Listed Companies</p>,
#  <p>Important Information, reference materials and latest announcements for members.</p>,
#  <p>ENIT - A Portal for Trading Members of NSE to manage their Membership and Compliance requirements.</p>,
#  <p>Browse Exchange circulars, press release and media articles.</p>,
#  <p>Click here to find a course</p>,
#  <p>Click here to join the platform</p>,
#  <p>NCFM Portal for online testing and certification programmes offered by NSE Academy.</p>,
#  <p>Find all communication issued by the Exchange in this section</p>,
#  <p>Daily and Archive Reports, Formats and Business Growth download it here</p>,
#  <p>Homepage for Researchers and Academia to participate in research initiatives</p>,
#  <p class="disc">You will be redirected to <br/>another link to complete the login</p>,
#  <p class="hide_on_collapse">A collective initiative against COVID-19
#                                  </p>,
#  <p> <a class="btn btn-common" href="https://www.mygov.in/aarogya-setu-app/">Know More</a> </p>,
#  <p class="hide_on_collapse">Shri Ashishkumar Chauhan, MD &amp; CEO, NSE &amp;<br/>Shri Loh Boon Chye, CEO, SGX Group<br/>presented a special memento at Gift City, Gandhinagar on July 29, 2022
#                                  </p>,
#  <p> <a class="btn btn-common" href="https://static.nseindia.com/s3fs-public/2022-07/PR_cc_29072022.pdf" tabindex="0">Know More</a> </p>,
#  <p class="hide_on_collapse">For the 3rd consecutive year - CY 2019, 2020 &amp; 2021. Based on<br/>number of contracts traded
#                                  </p>,
#  <p> <a class="btn btn-common" href="https://static.nseindia.com/s3fs-public/2022-01/PR_cc_19012022.pdf">Know More</a> </p>,
#  <p class="hide_on_collapse">A collective initiative against COVID-19
#                                  </p>,
#  <p> <a class="btn btn-common" href="https://www.mygov.in/aarogya-setu-app/">Know More</a> </p>,
#  <p class="hide_on_collapse">Shri Ashishkumar Chauhan, MD &amp; CEO, NSE &amp;<br/>Shri Loh Boon Chye, CEO, SGX Group<br/>presented a special memento at Gift City, Gandhinagar on July 29, 2022
#                                  </p>,
#  <p> <a class="btn btn-common" href="https://static.nseindia.com/s3fs-public/2022-07/PR_cc_29072022.pdf">Know More</a> </p>,
#  <p class="hide_on_collapse">For the 3rd consecutive year - CY 2019, 2020 &amp; 2021. Based on<br/>number of contracts traded
#                                  </p>,
#  <p> <a class="btn btn-common" href="https://static.nseindia.com/s3fs-public/2022-01/PR_cc_19012022.pdf">Know More</a> </p>,
#  <p class="hide_on_collapse">A collective initiative against COVID-19
#                                  </p>,
#  <p> <a class="btn btn-common" href="https://www.mygov.in/aarogya-setu-app/">Know More</a> </p>,
#  <p class="tb_name">NIFTY 50</p>,
#  <p class="tb_val">18,609.35 <span class="arrow"></span></p>,
#  <p class="tb_per greenTxt">48.85 (0.26%)</p>,
#  <p class="tb_name">NIFTY NEXT 50</p>,
#  <p class="tb_val">44,068.45 <span class="arrow"></span></p>,
#  <p class="tb_per greenTxt">176.25 (0.40%)</p>,
#  <p class="tb_name">NIFTY MIDCAP SELECT</p>,
#  <p class="tb_val">7,432.55 <span class="arrow"></span></p>,
#  <p class="tb_per greenTxt">21.50 (0.29%)</p>,
#  <p class="tb_name">NIFTY BANK</p>,
#  <p class="tb_val">43,596.85 <span class="arrow"></span></p>,
#  <p class="tb_per greenTxt">498.15 (1.16%)</p>,
#  <p class="tb_name">NIFTY FINANCIAL SERVICES</p>,
#  <p class="tb_val">19,292.40 <span class="arrow"></span></p>,
#  <p class="tb_per greenTxt">111.95 (0.58%)</p>,
#  <p>As on 08-Dec-2022 13:30:00 IST</p>,
#  <p>As on Dec 08, 2022 17:00:20 IST</p>,
#  <p>As on 08-DEC-2022 IST</p>,
#  <p class="line-corp overflowHidden">
#                                                  Other business matters
#                                              </p>,
#  <p class="line-corp overflowHidden">
#                                                  Dividend
#                                              </p>,
#  <p class="line-corp overflowHidden">
#                                                  Other business matters
#                                              </p>,
#  <p class="line-corp overflowHidden">
#                                                      Buyback
#                                                  </p>,
#  <p class="line-corp overflowHidden">
#                                                      Other business matters
#                                                  </p>,
#  <p class="line-corp overflowHidden">
#                                                      Other business matters
#                                                  </p>,
#  <p>Shri Ashishkumar Chauhan, Managing Director &amp; CEO, NSE presented a memento to Hon'ble Prime Minister Narendra Modi at the launch of NSE IFSC-SGX Connect.</p>,
#  <p>Update your contact details in KYC available with your broker and ensure that you get timely messages of all your investment transactions.</p>,
#  <p>Nukkad Natak – On Importance of financial Education</p>,
#  <p class="pb-2">NSE/CML/54768</p>,
#  <p>
#  <a href="https://archives.nseindia.com/content/circulars/CML54768.pdf" tabindex="0" target="_blank"> <img alt="icon-pdf" src="/assets/images/icon-pdf.svg"/>Download </a>
#  </p>,
#  <p class="pb-2">NSE/CML/54767</p>,
#  <p>
#  <a href="https://archives.nseindia.com/content/circulars/CML54767.pdf" tabindex="0" target="_blank"> <img alt="icon-pdf" src="/assets/images/icon-pdf.svg"/>Download </a>
#  </p>,
#  <p class="pb-2">NSE/SURV/54766</p>,
#  <p>
#  <a href="https://archives.nseindia.com/content/circulars/SURV54766.zip" tabindex="0" target="_blank"> <img alt="icon-zip" src="/assets/images/icon-zip.svg"/>Download </a>
#  </p>,
#  <p class="pb-2">NSE/COMP/54765</p>,
#  <p>
#  <a href="https://archives.nseindia.com/content/circulars/COMP54765.pdf" tabindex="0" target="_blank"> <img alt="icon-pdf" src="/assets/images/icon-pdf.svg"/>Download </a>
#  </p>,
#  <p class="pb-2">NSE/SURV/54764</p>,
#  <p>
#  <a href="https://archives.nseindia.com/content/circulars/SURV54764.zip" target="_blank"> <img alt="icon-zip" src="/assets/images/icon-zip.svg"/>Download </a>
#  </p>,
#  <p class="pb-2">NSE/CML/54763</p>,
#  <p>
#  <a href="https://archives.nseindia.com/content/circulars/CML54763.pdf" target="_blank"> <img alt="icon-pdf" src="/assets/images/icon-pdf.svg"/>Download </a>
#  </p>,
#  <p class="pb-2">NSE/SURV/54762</p>,
#  <p>
#  <a href="https://archives.nseindia.com/content/circulars/SURV54762.zip" target="_blank"> <img alt="icon-zip" src="/assets/images/icon-zip.svg"/>Download </a>
#  </p>,
#  <p class="pb-2">NSE/SURV/54761</p>,
#  <p>
#  <a href="https://archives.nseindia.com/content/circulars/SURV54761.zip" target="_blank"> <img alt="icon-zip" src="/assets/images/icon-zip.svg"/>Download </a>
#  </p>,
#  <p class="pb-2">NSE/DS/54760</p>,
#  <p>
#  <a href="https://archives.nseindia.com/content/circulars/DS54760.pdf" target="_blank"> <img alt="icon-pdf" src="/assets/images/icon-pdf.svg"/>Download </a>
#  </p>,
#  <p class="pb-2">NSE/FAOP/54759</p>,
#  <p>
#  <a href="https://archives.nseindia.com/content/circulars/FAOP54759.pdf" target="_blank"> <img alt="icon-pdf" src="/assets/images/icon-pdf.svg"/>Download </a>
#  </p>,
#  <p class="pb-2">NSE/COM/54758</p>,
#  <p>
#  <a href="https://archives.nseindia.com/content/circulars/COM54758.pdf" target="_blank"> <img alt="icon-pdf" src="/assets/images/icon-pdf.svg"/>Download </a>
#  </p>,
#  <p class="pb-2">NSE/CMTR/54757</p>,
#  <p>
#  <a href="https://archives.nseindia.com/content/circulars/CMTR54757.pdf" target="_blank"> <img alt="icon-pdf" src="/assets/images/icon-pdf.svg"/>Download </a>
#  </p>,
#  <p class="subtitle">NSE Indices</p>,
#  <p>NSE Indices launches Nifty SDL Sep 2026 V1 Index</p>,
#  <p>
#  <a href="https://static.nseindia.com/s3fs-public/2022-12/NSE Indices launches Nifty SDL Sep 2026 V1 Index.pdf" tabindex="0" target="_blank"><img alt="icon-pdf" src="/assets/images/icon-pdf.svg"/>Download </a>
#  </p>,
#  <p class="subtitle">NSE Listing</p>,
#  <p>Press Release</p>,
#  <p>
#  <a href="https://static.nseindia.com/s3fs-public/2022-12/PR_list_07122022.pdf" tabindex="0" target="_blank"><img alt="icon-pdf" src="/assets/images/icon-pdf.svg"/>Download </a>
#  </p>,
#  <p class="subtitle">NSE Listing </p>,
#  <p>Listing of equity shares of Sarveshwar Foods Limited on Capital Market Segment (Main Board) pursuant to migration from SME Emerge platform</p>,
#  <p>
#  <a href="https://static.nseindia.com/s3fs-public/2022-12/PR_List_06122022.pdf" tabindex="0" target="_blank"><img alt="icon-pdf" src="/assets/images/icon-pdf.svg"/>Download </a>
#  </p>,
#  <p class="subtitle">NSE Clearing</p>,
#  <p>Market-wide Position Limit in PNB</p>,
#  <p>
#  <a href="https://static.nseindia.com/s3fs-public/2022-12/PR_nsccl_06122022.pdf" tabindex="0" target="_blank"><img alt="icon-pdf" src="/assets/images/icon-pdf.svg"/>Download </a>
#  </p>,
#  <p class="subtitle">Surveillance</p>,
#  <p>News about Aditya Birla Fashion and Retail Limited</p>,
#  <p>Clarification by Advanced Enzyme Technologies Limited</p>,
#  <p>Clarification by Aptus Value Housing Finance India Limited</p>,
#  <p>Clarification by Capri Global Capital Limited</p>,
#  <p>Clarification by Country Condo's Limited</p>,
#  <p>Clarification by Gujarat Fluorochemicals Limited</p>,
#  <p>News about IIFL Securities Limited</p>,
#  <p>Clarification by Indian Terrain Fashions Limited</p>,
#  <p>Clarification by Medplus Health Services Limited</p>,
#  <p>Clarification by PNC Infratech Limited</p>,
#  <p>Clarification by Ponni Sugars (Erode) Limited</p>,
#  <p>News about Power Finance Corporation Limited</p>,
#  <p>Clarification by Puravankara Limited</p>,
#  <p>News about REC Limited</p>,
#  <p>Clarification by Rainbow Childrens Medicare Limited</p>,
#  <p>Clarification by Sharda Cropchem Limited</p>,
#  <p>News about TCNS Clothing Co. Limited</p>,
#  <p>News about Tata Power Company Limited</p>,
#  <p>Clarification by Tega Industries Limited</p>,
#  <p>Clarification by Yaari Digital Integrated Services Limited</p>,
#  <p>
#  <a href="https://static.nseindia.com/s3fs-public/2022-12/PR_surv_06122022_0.pdf" target="_blank"><img alt="icon-pdf" src="/assets/images/icon-pdf.svg"/>Download </a>
#  </p>,
#  <p class="subtitle">Corporate Communications</p>,
#  <p>Shri Injeti Srinivas, Chairman, International Financial Services Authority (IFSCA) visits NSE</p>,
#  <p>
#  <a href="https://static.nseindia.com/s3fs-public/2022-11/PR_cc_22092022.pdf" tabindex="0" target="_blank"><img alt="icon-pdf" src="/assets/images/icon-pdf.svg"/>Download </a>
#  </p>,
#  <p class="subtitle">Corporate Communications</p>,
#  <p>22 years of partnership between NSE and SGX for NIFTY50</p>,
#  <p>
#  <a href="https://static.nseindia.com/s3fs-public/2022-11/PR_cc_19092022.pdf" tabindex="0" target="_blank"><img alt="icon-pdf" src="/assets/images/icon-pdf.svg"/>Download </a>
#  </p>,
#  <p class="subtitle">Corporate Communications</p>,
#  <p>Caution for Investors</p>,
#  <p>
#  <a href="https://static.nseindia.com/s3fs-public/2022-11/PR_cc_23082022_0.pdf" tabindex="0" target="_blank"><img alt="icon-pdf" src="/assets/images/icon-pdf.svg"/>Download </a>
#  </p>,
#  <p class="subtitle">Corporate Communications</p>,
#  <p>Shri. Ashishkumar Chauhan, MD &amp; CEO, NSE meets Shri. Bhupendra Patel, Gujarat's chief minister, at the CM office, Sachivalaya in Gandhinagar, Gujarat</p>,
#  <p>
#  <a href="https://static.nseindia.com/s3fs-public/2022-11/PR_cc_18082022.pdf" tabindex="0" target="_blank"><img alt="icon-pdf" src="/assets/images/icon-pdf.svg"/>Download </a>
#  </p>,
#  <p class="subtitle">Corporate Communications</p>,
#  <p>NSE Statement and MD &amp; CEO quote on Independence Day</p>,
#  <p>
#  <a href="https://static.nseindia.com/s3fs-public/2022-11/PR_cc_14082022.pdf" target="_blank"><img alt="icon-pdf" src="/assets/images/icon-pdf.svg"/>Download </a>
#  </p>,
#  <p>
#                          Email:
#                          <a href="mailto:Feedbk_invg@nse.co.in">Feedbk_invg@nse.co.in</a>
#  </p>,
#  <p>
#  <a class="btn btn-common" href="/submit-tipoff">Submit a tip off</a>
#  </p>,
#  <p>
#                          Email:
#                          <a href="mailto:Feedbk_invg@nse.co.in">Feedbk_invg@nse.co.in</a>
#  </p>,
#  <p>
#  <a class="btn btn-common" href="/regulations/unsolicited-messages-report">Report here</a>
#  </p>,
#  <p>
#  <a class="btn btn-common" href="/contact/corporate-office">Call Centre For Members</a>
#  </p>,
#  <p>Choose upto 5 indices that you would like to view the market trend for.</p>,
#  <p>
#  <a href="https://itunes.apple.com/us/app/nse-nmf-ii/id1227619380?mt=8" rel="nofollow noopener" target="_blank" title="Download NSE NMFII on Apple Store">
#  <img alt="Download NSE NMFII on Apple Store" src="/assets/images/download-apple-store.svg" title=" Download NSE NMFII on Apple Store"/>
#  </a>
#  <a href="https://play.google.com/store/apps/details?id=coms.nsenmf.nsenmf&amp;hl=en" rel="nofollow noopener" target="_blank" title="Download NSE NMFII on Google Play Store">
#  <img alt="Download NSE NMFII on Google Play Store" src="/assets/images/download-google-store.svg" title="Download NSE NMFII on Google Play Store"/>
#  </a>
#  </p>,
#  <p>
#  <a href="https://play.google.com/store/apps/details?id=com.xlx.eipodc" rel="nofollow noopener" target="_blank" title="Download NSE MOBILE on Google Play Store">
#  <img alt="Download NSE GO-BID on Google Play Store" src="/assets/images/download-google-store.svg" title="Download NSE GO-BID on Google Play Store"/>
#  </a>
#  </p>,
#  <p class="m-0">Dashboard for end of day reports download, quick market snapshot and important announcements.</p>,
#  <p class="m-0"><span class="asondate">As on <span></span> IST</span></p>,
#  <p id="qlopen">-</p>,
#  <p id="qlhigh">-</p>,
#  <p id="qllow">-</p>,
#  <p id="qlclose">-</p>,
#  <p class="val_heading">Volume <small>(Lakhs)</small></p>,
#  <p class="mkt_val" id="qlvolume"></p>,
#  <p class="val_heading">Value <small>(Lakhs)</small></p>,
#  <p class="mkt_val" id="qlvalue"></p>,
#  <p class="val_heading" title="Free Float Market Capitalization (in Rs. Lakhs)">FFM .Cap <small>(Lakhs)</small></p>,
#  <p class="mkt_val" id="qlffmc"></p>,
#  <p class="m-0">Dashboard for tracking corporate filings</p>,
#  <p class="m-0"> Exchange has published Member Help Guide and new FAQs for Access to Markets. Visit the link: https://www.nseindia.com/trade/all-member-faqs</p>]

# %%
para = soup.find_all('p')
for p in para:
     print(p.get_text())
# Out:
# Debt Market is Closed
# Next
#                                             Trading Date - 09-Dec-2022
# Normal Market has Closed
# Next
#                                             Trading Date - 09-Dec-2022
# Currency Market is Closed
# Next
#                                             Trading Date - 09-Dec-2022
# Commodity Market is Open
# Current
#                                             Trading Date - 08-Dec-2022
# Debt Market is Closed
# Next
#                                             Trading Date - 09-Dec-2022
# Normal Market has Closed
# Next
#                                             Trading Date - 09-Dec-2022
# Currency Market is Closed
# Next
#                                             Trading Date - 09-Dec-2022
# Commodity Market is Open
# Current
#                                             Trading Date - 08-Dec-2022
# Debt Market is Closed
# Next
#                                             Trading Date - 09-Dec-2022
# Find everything about the leading stock exchange of India
# Check NSE's group of the companies
# Browse a comprehensive and innovative product and service offerings by NSE
# Live Analysis of top gainers/losers, most active securities/contracts, price band hitters, overview of the market.
# View Option chain for the exchange
# Screen stocks based on key fundamentals with the NSE Stock Screener to make your investing a more process-driven.
# Investor education on how to invest safely and protect your investments.
# Browse NSE products under Cash, derivatives, currency derivatives etc.
# File and Track your Complaint online.
# Important information, reference material and latest announcements for corporates
# Status of compliance's under various Regulatory requirements
# Login for Listed Companies
# Important Information, reference materials and latest announcements for members.
# ENIT - A Portal for Trading Members of NSE to manage their Membership and Compliance requirements.
# Browse Exchange circulars, press release and media articles.
# Click here to find a course
# Click here to join the platform
# NCFM Portal for online testing and certification programmes offered by NSE Academy.
# Find all communication issued by the Exchange in this section
# Daily and Archive Reports, Formats and Business Growth download it here
# Homepage for Researchers and Academia to participate in research initiatives
# You will be redirected to another link to complete the login
# A collective initiative against COVID-19
#
#  Know More
# Shri Ashishkumar Chauhan, MD & CEO, NSE &Shri Loh Boon Chye, CEO, SGX Grouppresented a special memento at Gift City, Gandhinagar on July 29, 2022
#
#  Know More
# For the 3rd consecutive year - CY 2019, 2020 & 2021. Based onnumber of contracts traded
#
#  Know More
# A collective initiative against COVID-19
#
#  Know More
# Shri Ashishkumar Chauhan, MD & CEO, NSE &Shri Loh Boon Chye, CEO, SGX Grouppresented a special memento at Gift City, Gandhinagar on July 29, 2022
#
#  Know More
# For the 3rd consecutive year - CY 2019, 2020 & 2021. Based onnumber of contracts traded
#
#  Know More
# A collective initiative against COVID-19
#
#  Know More
# NIFTY 50
# 18,609.35
# 48.85 (0.26%)
# NIFTY NEXT 50
# 44,068.45
# 176.25 (0.40%)
# NIFTY MIDCAP SELECT
# 7,432.55
# 21.50 (0.29%)
# NIFTY BANK
# 43,596.85
# 498.15 (1.16%)
# NIFTY FINANCIAL SERVICES
# 19,292.40
# 111.95 (0.58%)
# As on 08-Dec-2022 13:30:00 IST
# As on Dec 08, 2022 17:00:20 IST
# As on 08-DEC-2022 IST
#
#                                                 Other business matters
#
#
#                                                 Dividend
#
#
#                                                 Other business matters
#
#
#                                                     Buyback
#
#
#                                                     Other business matters
#
#
#                                                     Other business matters
#
# Shri Ashishkumar Chauhan, Managing Director & CEO, NSE presented a memento to Hon'ble Prime Minister Narendra Modi at the launch of NSE IFSC-SGX Connect.
# Update your contact details in KYC available with your broker and ensure that you get timely messages of all your investment transactions.
# Nukkad Natak – On Importance of financial Education
# NSE/CML/54768
#
#  Download
#
# NSE/CML/54767
#
#  Download
#
# NSE/SURV/54766
#
#  Download
#
# NSE/COMP/54765
#
#  Download
#
# NSE/SURV/54764
#
#  Download
#
# NSE/CML/54763
#
#  Download
#
# NSE/SURV/54762
#
#  Download
#
# NSE/SURV/54761
#
#  Download
#
# NSE/DS/54760
#
#  Download
#
# NSE/FAOP/54759
#
#  Download
#
# NSE/COM/54758
#
#  Download
#
# NSE/CMTR/54757
#
#  Download
#
# NSE Indices
# NSE Indices launches Nifty SDL Sep 2026 V1 Index
#
# Download
#
# NSE Listing
# Press Release
#
# Download
#
# NSE Listing
# Listing of equity shares of Sarveshwar Foods Limited on Capital Market Segment (Main Board) pursuant to migration from SME Emerge platform
#
# Download
#
# NSE Clearing
# Market-wide Position Limit in PNB
#
# Download
#
# Surveillance
# News about Aditya Birla Fashion and Retail Limited
# Clarification by Advanced Enzyme Technologies Limited
# Clarification by Aptus Value Housing Finance India Limited
# Clarification by Capri Global Capital Limited
# Clarification by Country Condo's Limited
# Clarification by Gujarat Fluorochemicals Limited
# News about IIFL Securities Limited
# Clarification by Indian Terrain Fashions Limited
# Clarification by Medplus Health Services Limited
# Clarification by PNC Infratech Limited
# Clarification by Ponni Sugars (Erode) Limited
# News about Power Finance Corporation Limited
# Clarification by Puravankara Limited
# News about REC Limited
# Clarification by Rainbow Childrens Medicare Limited
# Clarification by Sharda Cropchem Limited
# News about TCNS Clothing Co. Limited
# News about Tata Power Company Limited
# Clarification by Tega Industries Limited
# Clarification by Yaari Digital Integrated Services Limited
#
# Download
#
# Corporate Communications
# Shri Injeti Srinivas, Chairman, International Financial Services Authority (IFSCA) visits NSE
#
# Download
#
# Corporate Communications
# 22 years of partnership between NSE and SGX for NIFTY50
#
# Download
#
# Corporate Communications
# Caution for Investors
#
# Download
#
# Corporate Communications
# Shri. Ashishkumar Chauhan, MD & CEO, NSE meets Shri. Bhupendra Patel, Gujarat's chief minister, at the CM office, Sachivalaya in Gandhinagar, Gujarat
#
# Download
#
# Corporate Communications
# NSE Statement and MD & CEO quote on Independence Day
#
# Download
#
#
#                         Email:
#                         Feedbk_invg@nse.co.in
#
#
# Submit a tip off
#
#
#                         Email:
#                         Feedbk_invg@nse.co.in
#
#
# Report here
#
#
# Call Centre For Members
#
# Choose upto 5 indices that you would like to view the market trend for.
#
#
#
#
#
#
#
#
#
#
#
#
#
# Dashboard for end of day reports download, quick market snapshot and important announcements.
# As on  IST
# -
# -
# -
# -
# Volume (Lakhs)
#
# Value (Lakhs)
#
# FFM .Cap (Lakhs)
#
# Dashboard for tracking corporate filings
#  Exchange has published Member Help Guide and new FAQs for Access to Markets. Visit the link: https://www.nseindia.com/trade/all-member-faqs

# %%
Nifty = soup.find_all('p', {'class':'tb_name'})
for name in Nifty:
     print(name.get_text())
# Out:
# NIFTY 50
# NIFTY NEXT 50
# NIFTY MIDCAP SELECT
# NIFTY BANK
# NIFTY FINANCIAL SERVICES

# %%
Nifty = soup.findAll('p', {'class':'tb_name'})
value = soup.findAll('p', {'class':'tb_val'})
for Nifty_name in Nifty:
     print(Nifty_name.get_text())
for Nifty_value in value:
     print(Nifty_value.get_text())
# Out:
# NIFTY 50
# NIFTY NEXT 50
# NIFTY MIDCAP SELECT
# NIFTY BANK
# NIFTY FINANCIAL SERVICES
# 18,609.35
# 44,068.45
# 7,432.55
# 43,596.85
# 19,292.40

# %%
div=soup.find_all("div")
div
# Out:
# [<div id="pageLoader">
#  <div class="loader-wrp">
#  <div aria-hidden="true" class="spin-loader"></div>
#  </div>
#  </div>,
#  <div class="loader-wrp">
#  <div aria-hidden="true" class="spin-loader"></div>
#  </div>,
#  <div aria-hidden="true" class="spin-loader"></div>,
#  <div id="betaVerBand">YOU ARE ON THE NEW NSE WEBSITE, ACCESS THE OLD WEBSITE ON THE URL <a href="https://www1.nseindia.com/index_nse.htm " target="_blank">www1.nseindia.com</a>
#  </div>,
#  <div class="container top_logomenu">
#  <a class="navbar-brand mr-auto" href="/"><img alt="NSE India" height="44" src="/assets/images/NSE_Logo.svg" title="NSE India, National Stock Exchange" width="128"/></a>
#  <button aria-controls="main_navbar" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#main_navbar" data-toggle="collapse" type="button">
#  <span class="navbar-toggler-icon"></span></button>
#  <div class="middleheader">
#  <div class="searchbox">
#  <div class="inputbox">
#  <span class="twitter-typeahead" style="position: relative; display: inline-block;"><input aria-activedescendant="" aria-autocomplete="list" aria-controls="autoComplete" aria-expanded="false" aria-owns="autoComplete" autocomplete="off" class="typeahead tt-input" dir="auto" id="header-search-input" placeholder="Search by company name, symbol or keyword" role="combobox" spellcheck="false" style="position: relative; vertical-align: top;" type="text"/><span aria-live="polite" role="status" style="position: absolute; padding: 0px; border: 0px; height: 1px; width: 1px; margin-bottom: -1px; margin-right: -1px; overflow: hidden; clip: rect(0px, 0px, 0px, 0px); white-space: nowrap;"></span><pre aria-hidden="true" style="position: absolute; visibility: hidden; white-space: pre; font-family: Roboto; font-size: 12px; font-style: normal; font-variant: normal; font-weight: 600; word-spacing: 0px; letter-spacing: 0px; text-indent: 0px; text-rendering: auto; text-transform: none;"></pre><div class="tt-menu" role="listbox" style="position: absolute; top: 100%; left: 0px; z-index: 100; display: none;"><div class="tt-dataset tt-dataset-search" role="presentation"></div></div></span>
#  <button aria-label="Click to Serach"><img alt="Get Quote Search" height="24" src="/assets/images/Get_Quote_search.svg" title="Get Quote Search" width="24"/></button>
#  </div>
#  <div class="searchAuto" id="autoComplete"><ul id="autoCompleteBlock"></ul></div>
#  </div>
#  </div>
#  <div class="form-inline top-right ml-auto my-2 my-lg-0 niftyMarket" id="nseMarketStatus">
#  <div class="innerContainer slick-initialized slick-slider slick-vertical" style="position: relative; height: 268px;">
#  <div class="slick-list draggable" style="height: 67px;"><div class="slick-track" style="opacity: 1; height: 603px; transform: translate3d(0px, -67px, 0px);"><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="-1" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="false" class="form-inline niftyFifty slick-slide slick-current slick-active" data-slick-index="0" style="width: 331px;" tabindex="0">
#  <div class="logo_with_text">
#  <figure class="capitalLogo">
#  <img alt="NSE - NIFTY 50" src="/assets/images/logo_nifty50.png" title="NSE - NIFTY 50"/>
#  </figure>
#  <p class="redTxt" id="capMarStat">Normal Market has Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_head" id="marketStat0">
#  <div class="index_val">
#  <span class="val ltp">18,609.35
#                                                  <i class="fa fa-caret-up cool-green"></i>
#  </span>
#  </div>
#  <div class="incr_dcr">
#  <span class="per greenTxt">48.85 (0.26%)</span>
#  </div>
#  </div>
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide" data-slick-index="1" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="currencyLogo">
#  <img alt="NSE - Currency Derivative" src="/assets/images/logo_currencyDer.png" title="NSE - Currency Derivative"/>
#  </figure>
#  <p class="redTxt">Currency Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide" data-slick-index="2" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Commodity Derivative" src="/assets/images/logo_commodityDer.png" title="NSE - Commodity Derivative"/>
#  </figure>
#  <p class="greenTxt">Commodity Market is Open</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Current
#                                              Trading Date - 08-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide" data-slick-index="3" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="4" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="capitalLogo">
#  <img alt="NSE - NIFTY 50" src="/assets/images/logo_nifty50.png" title="NSE - NIFTY 50"/>
#  </figure>
#  <p class="redTxt" id="">Normal Market has Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_head" id="">
#  <div class="index_val">
#  <span class="val ltp">18,609.35
#                                                  <i class="fa fa-caret-up cool-green"></i>
#  </span>
#  </div>
#  <div class="incr_dcr">
#  <span class="per greenTxt">48.85 (0.26%)</span>
#  </div>
#  </div>
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="5" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="currencyLogo">
#  <img alt="NSE - Currency Derivative" src="/assets/images/logo_currencyDer.png" title="NSE - Currency Derivative"/>
#  </figure>
#  <p class="redTxt">Currency Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="6" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Commodity Derivative" src="/assets/images/logo_commodityDer.png" title="NSE - Commodity Derivative"/>
#  </figure>
#  <p class="greenTxt">Commodity Market is Open</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Current
#                                              Trading Date - 08-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="7" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div></div></div>
#  </div>
#  <button aria-label="playpause" class="play_pause_btn position-absolute" role="button"><i class="fa fa-pause-circle"></i></button>
#  </div>
#  <!--<div class="form-inline top-right ml-auto my-2 my-lg-0"></div>-->
#  </div>,
#  <div class="middleheader">
#  <div class="searchbox">
#  <div class="inputbox">
#  <span class="twitter-typeahead" style="position: relative; display: inline-block;"><input aria-activedescendant="" aria-autocomplete="list" aria-controls="autoComplete" aria-expanded="false" aria-owns="autoComplete" autocomplete="off" class="typeahead tt-input" dir="auto" id="header-search-input" placeholder="Search by company name, symbol or keyword" role="combobox" spellcheck="false" style="position: relative; vertical-align: top;" type="text"/><span aria-live="polite" role="status" style="position: absolute; padding: 0px; border: 0px; height: 1px; width: 1px; margin-bottom: -1px; margin-right: -1px; overflow: hidden; clip: rect(0px, 0px, 0px, 0px); white-space: nowrap;"></span><pre aria-hidden="true" style="position: absolute; visibility: hidden; white-space: pre; font-family: Roboto; font-size: 12px; font-style: normal; font-variant: normal; font-weight: 600; word-spacing: 0px; letter-spacing: 0px; text-indent: 0px; text-rendering: auto; text-transform: none;"></pre><div class="tt-menu" role="listbox" style="position: absolute; top: 100%; left: 0px; z-index: 100; display: none;"><div class="tt-dataset tt-dataset-search" role="presentation"></div></div></span>
#  <button aria-label="Click to Serach"><img alt="Get Quote Search" height="24" src="/assets/images/Get_Quote_search.svg" title="Get Quote Search" width="24"/></button>
#  </div>
#  <div class="searchAuto" id="autoComplete"><ul id="autoCompleteBlock"></ul></div>
#  </div>
#  </div>,
#  <div class="searchbox">
#  <div class="inputbox">
#  <span class="twitter-typeahead" style="position: relative; display: inline-block;"><input aria-activedescendant="" aria-autocomplete="list" aria-controls="autoComplete" aria-expanded="false" aria-owns="autoComplete" autocomplete="off" class="typeahead tt-input" dir="auto" id="header-search-input" placeholder="Search by company name, symbol or keyword" role="combobox" spellcheck="false" style="position: relative; vertical-align: top;" type="text"/><span aria-live="polite" role="status" style="position: absolute; padding: 0px; border: 0px; height: 1px; width: 1px; margin-bottom: -1px; margin-right: -1px; overflow: hidden; clip: rect(0px, 0px, 0px, 0px); white-space: nowrap;"></span><pre aria-hidden="true" style="position: absolute; visibility: hidden; white-space: pre; font-family: Roboto; font-size: 12px; font-style: normal; font-variant: normal; font-weight: 600; word-spacing: 0px; letter-spacing: 0px; text-indent: 0px; text-rendering: auto; text-transform: none;"></pre><div class="tt-menu" role="listbox" style="position: absolute; top: 100%; left: 0px; z-index: 100; display: none;"><div class="tt-dataset tt-dataset-search" role="presentation"></div></div></span>
#  <button aria-label="Click to Serach"><img alt="Get Quote Search" height="24" src="/assets/images/Get_Quote_search.svg" title="Get Quote Search" width="24"/></button>
#  </div>
#  <div class="searchAuto" id="autoComplete"><ul id="autoCompleteBlock"></ul></div>
#  </div>,
#  <div class="inputbox">
#  <span class="twitter-typeahead" style="position: relative; display: inline-block;"><input aria-activedescendant="" aria-autocomplete="list" aria-controls="autoComplete" aria-expanded="false" aria-owns="autoComplete" autocomplete="off" class="typeahead tt-input" dir="auto" id="header-search-input" placeholder="Search by company name, symbol or keyword" role="combobox" spellcheck="false" style="position: relative; vertical-align: top;" type="text"/><span aria-live="polite" role="status" style="position: absolute; padding: 0px; border: 0px; height: 1px; width: 1px; margin-bottom: -1px; margin-right: -1px; overflow: hidden; clip: rect(0px, 0px, 0px, 0px); white-space: nowrap;"></span><pre aria-hidden="true" style="position: absolute; visibility: hidden; white-space: pre; font-family: Roboto; font-size: 12px; font-style: normal; font-variant: normal; font-weight: 600; word-spacing: 0px; letter-spacing: 0px; text-indent: 0px; text-rendering: auto; text-transform: none;"></pre><div class="tt-menu" role="listbox" style="position: absolute; top: 100%; left: 0px; z-index: 100; display: none;"><div class="tt-dataset tt-dataset-search" role="presentation"></div></div></span>
#  <button aria-label="Click to Serach"><img alt="Get Quote Search" height="24" src="/assets/images/Get_Quote_search.svg" title="Get Quote Search" width="24"/></button>
#  </div>,
#  <div class="tt-menu" role="listbox" style="position: absolute; top: 100%; left: 0px; z-index: 100; display: none;"><div class="tt-dataset tt-dataset-search" role="presentation"></div></div>,
#  <div class="tt-dataset tt-dataset-search" role="presentation"></div>,
#  <div class="searchAuto" id="autoComplete"><ul id="autoCompleteBlock"></ul></div>,
#  <div class="form-inline top-right ml-auto my-2 my-lg-0 niftyMarket" id="nseMarketStatus">
#  <div class="innerContainer slick-initialized slick-slider slick-vertical" style="position: relative; height: 268px;">
#  <div class="slick-list draggable" style="height: 67px;"><div class="slick-track" style="opacity: 1; height: 603px; transform: translate3d(0px, -67px, 0px);"><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="-1" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="false" class="form-inline niftyFifty slick-slide slick-current slick-active" data-slick-index="0" style="width: 331px;" tabindex="0">
#  <div class="logo_with_text">
#  <figure class="capitalLogo">
#  <img alt="NSE - NIFTY 50" src="/assets/images/logo_nifty50.png" title="NSE - NIFTY 50"/>
#  </figure>
#  <p class="redTxt" id="capMarStat">Normal Market has Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_head" id="marketStat0">
#  <div class="index_val">
#  <span class="val ltp">18,609.35
#                                                  <i class="fa fa-caret-up cool-green"></i>
#  </span>
#  </div>
#  <div class="incr_dcr">
#  <span class="per greenTxt">48.85 (0.26%)</span>
#  </div>
#  </div>
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide" data-slick-index="1" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="currencyLogo">
#  <img alt="NSE - Currency Derivative" src="/assets/images/logo_currencyDer.png" title="NSE - Currency Derivative"/>
#  </figure>
#  <p class="redTxt">Currency Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide" data-slick-index="2" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Commodity Derivative" src="/assets/images/logo_commodityDer.png" title="NSE - Commodity Derivative"/>
#  </figure>
#  <p class="greenTxt">Commodity Market is Open</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Current
#                                              Trading Date - 08-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide" data-slick-index="3" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="4" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="capitalLogo">
#  <img alt="NSE - NIFTY 50" src="/assets/images/logo_nifty50.png" title="NSE - NIFTY 50"/>
#  </figure>
#  <p class="redTxt" id="">Normal Market has Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_head" id="">
#  <div class="index_val">
#  <span class="val ltp">18,609.35
#                                                  <i class="fa fa-caret-up cool-green"></i>
#  </span>
#  </div>
#  <div class="incr_dcr">
#  <span class="per greenTxt">48.85 (0.26%)</span>
#  </div>
#  </div>
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="5" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="currencyLogo">
#  <img alt="NSE - Currency Derivative" src="/assets/images/logo_currencyDer.png" title="NSE - Currency Derivative"/>
#  </figure>
#  <p class="redTxt">Currency Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="6" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Commodity Derivative" src="/assets/images/logo_commodityDer.png" title="NSE - Commodity Derivative"/>
#  </figure>
#  <p class="greenTxt">Commodity Market is Open</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Current
#                                              Trading Date - 08-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="7" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div></div></div>
#  </div>
#  <button aria-label="playpause" class="play_pause_btn position-absolute" role="button"><i class="fa fa-pause-circle"></i></button>
#  </div>,
#  <div class="innerContainer slick-initialized slick-slider slick-vertical" style="position: relative; height: 268px;">
#  <div class="slick-list draggable" style="height: 67px;"><div class="slick-track" style="opacity: 1; height: 603px; transform: translate3d(0px, -67px, 0px);"><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="-1" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="false" class="form-inline niftyFifty slick-slide slick-current slick-active" data-slick-index="0" style="width: 331px;" tabindex="0">
#  <div class="logo_with_text">
#  <figure class="capitalLogo">
#  <img alt="NSE - NIFTY 50" src="/assets/images/logo_nifty50.png" title="NSE - NIFTY 50"/>
#  </figure>
#  <p class="redTxt" id="capMarStat">Normal Market has Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_head" id="marketStat0">
#  <div class="index_val">
#  <span class="val ltp">18,609.35
#                                                  <i class="fa fa-caret-up cool-green"></i>
#  </span>
#  </div>
#  <div class="incr_dcr">
#  <span class="per greenTxt">48.85 (0.26%)</span>
#  </div>
#  </div>
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide" data-slick-index="1" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="currencyLogo">
#  <img alt="NSE - Currency Derivative" src="/assets/images/logo_currencyDer.png" title="NSE - Currency Derivative"/>
#  </figure>
#  <p class="redTxt">Currency Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide" data-slick-index="2" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Commodity Derivative" src="/assets/images/logo_commodityDer.png" title="NSE - Commodity Derivative"/>
#  </figure>
#  <p class="greenTxt">Commodity Market is Open</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Current
#                                              Trading Date - 08-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide" data-slick-index="3" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="4" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="capitalLogo">
#  <img alt="NSE - NIFTY 50" src="/assets/images/logo_nifty50.png" title="NSE - NIFTY 50"/>
#  </figure>
#  <p class="redTxt" id="">Normal Market has Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_head" id="">
#  <div class="index_val">
#  <span class="val ltp">18,609.35
#                                                  <i class="fa fa-caret-up cool-green"></i>
#  </span>
#  </div>
#  <div class="incr_dcr">
#  <span class="per greenTxt">48.85 (0.26%)</span>
#  </div>
#  </div>
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="5" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="currencyLogo">
#  <img alt="NSE - Currency Derivative" src="/assets/images/logo_currencyDer.png" title="NSE - Currency Derivative"/>
#  </figure>
#  <p class="redTxt">Currency Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="6" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Commodity Derivative" src="/assets/images/logo_commodityDer.png" title="NSE - Commodity Derivative"/>
#  </figure>
#  <p class="greenTxt">Commodity Market is Open</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Current
#                                              Trading Date - 08-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="7" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div></div></div>
#  </div>,
#  <div class="slick-list draggable" style="height: 67px;"><div class="slick-track" style="opacity: 1; height: 603px; transform: translate3d(0px, -67px, 0px);"><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="-1" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="false" class="form-inline niftyFifty slick-slide slick-current slick-active" data-slick-index="0" style="width: 331px;" tabindex="0">
#  <div class="logo_with_text">
#  <figure class="capitalLogo">
#  <img alt="NSE - NIFTY 50" src="/assets/images/logo_nifty50.png" title="NSE - NIFTY 50"/>
#  </figure>
#  <p class="redTxt" id="capMarStat">Normal Market has Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_head" id="marketStat0">
#  <div class="index_val">
#  <span class="val ltp">18,609.35
#                                                  <i class="fa fa-caret-up cool-green"></i>
#  </span>
#  </div>
#  <div class="incr_dcr">
#  <span class="per greenTxt">48.85 (0.26%)</span>
#  </div>
#  </div>
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide" data-slick-index="1" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="currencyLogo">
#  <img alt="NSE - Currency Derivative" src="/assets/images/logo_currencyDer.png" title="NSE - Currency Derivative"/>
#  </figure>
#  <p class="redTxt">Currency Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide" data-slick-index="2" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Commodity Derivative" src="/assets/images/logo_commodityDer.png" title="NSE - Commodity Derivative"/>
#  </figure>
#  <p class="greenTxt">Commodity Market is Open</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Current
#                                              Trading Date - 08-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide" data-slick-index="3" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="4" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="capitalLogo">
#  <img alt="NSE - NIFTY 50" src="/assets/images/logo_nifty50.png" title="NSE - NIFTY 50"/>
#  </figure>
#  <p class="redTxt" id="">Normal Market has Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_head" id="">
#  <div class="index_val">
#  <span class="val ltp">18,609.35
#                                                  <i class="fa fa-caret-up cool-green"></i>
#  </span>
#  </div>
#  <div class="incr_dcr">
#  <span class="per greenTxt">48.85 (0.26%)</span>
#  </div>
#  </div>
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="5" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="currencyLogo">
#  <img alt="NSE - Currency Derivative" src="/assets/images/logo_currencyDer.png" title="NSE - Currency Derivative"/>
#  </figure>
#  <p class="redTxt">Currency Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="6" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Commodity Derivative" src="/assets/images/logo_commodityDer.png" title="NSE - Commodity Derivative"/>
#  </figure>
#  <p class="greenTxt">Commodity Market is Open</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Current
#                                              Trading Date - 08-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="7" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div></div></div>,
#  <div class="slick-track" style="opacity: 1; height: 603px; transform: translate3d(0px, -67px, 0px);"><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="-1" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="false" class="form-inline niftyFifty slick-slide slick-current slick-active" data-slick-index="0" style="width: 331px;" tabindex="0">
#  <div class="logo_with_text">
#  <figure class="capitalLogo">
#  <img alt="NSE - NIFTY 50" src="/assets/images/logo_nifty50.png" title="NSE - NIFTY 50"/>
#  </figure>
#  <p class="redTxt" id="capMarStat">Normal Market has Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_head" id="marketStat0">
#  <div class="index_val">
#  <span class="val ltp">18,609.35
#                                                  <i class="fa fa-caret-up cool-green"></i>
#  </span>
#  </div>
#  <div class="incr_dcr">
#  <span class="per greenTxt">48.85 (0.26%)</span>
#  </div>
#  </div>
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide" data-slick-index="1" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="currencyLogo">
#  <img alt="NSE - Currency Derivative" src="/assets/images/logo_currencyDer.png" title="NSE - Currency Derivative"/>
#  </figure>
#  <p class="redTxt">Currency Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide" data-slick-index="2" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Commodity Derivative" src="/assets/images/logo_commodityDer.png" title="NSE - Commodity Derivative"/>
#  </figure>
#  <p class="greenTxt">Commodity Market is Open</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Current
#                                              Trading Date - 08-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide" data-slick-index="3" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="4" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="capitalLogo">
#  <img alt="NSE - NIFTY 50" src="/assets/images/logo_nifty50.png" title="NSE - NIFTY 50"/>
#  </figure>
#  <p class="redTxt" id="">Normal Market has Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_head" id="">
#  <div class="index_val">
#  <span class="val ltp">18,609.35
#                                                  <i class="fa fa-caret-up cool-green"></i>
#  </span>
#  </div>
#  <div class="incr_dcr">
#  <span class="per greenTxt">48.85 (0.26%)</span>
#  </div>
#  </div>
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="5" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="currencyLogo">
#  <img alt="NSE - Currency Derivative" src="/assets/images/logo_currencyDer.png" title="NSE - Currency Derivative"/>
#  </figure>
#  <p class="redTxt">Currency Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="6" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Commodity Derivative" src="/assets/images/logo_commodityDer.png" title="NSE - Commodity Derivative"/>
#  </figure>
#  <p class="greenTxt">Commodity Market is Open</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Current
#                                              Trading Date - 08-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div><div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="7" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div></div>,
#  <div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="-1" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>,
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>,
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>,
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>,
#  <div aria-hidden="false" class="form-inline niftyFifty slick-slide slick-current slick-active" data-slick-index="0" style="width: 331px;" tabindex="0">
#  <div class="logo_with_text">
#  <figure class="capitalLogo">
#  <img alt="NSE - NIFTY 50" src="/assets/images/logo_nifty50.png" title="NSE - NIFTY 50"/>
#  </figure>
#  <p class="redTxt" id="capMarStat">Normal Market has Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_head" id="marketStat0">
#  <div class="index_val">
#  <span class="val ltp">18,609.35
#                                                  <i class="fa fa-caret-up cool-green"></i>
#  </span>
#  </div>
#  <div class="incr_dcr">
#  <span class="per greenTxt">48.85 (0.26%)</span>
#  </div>
#  </div>
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="logo_with_text">
#  <figure class="capitalLogo">
#  <img alt="NSE - NIFTY 50" src="/assets/images/logo_nifty50.png" title="NSE - NIFTY 50"/>
#  </figure>
#  <p class="redTxt" id="capMarStat">Normal Market has Closed</p>
#  </div>,
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_head" id="marketStat0">
#  <div class="index_val">
#  <span class="val ltp">18,609.35
#                                                  <i class="fa fa-caret-up cool-green"></i>
#  </span>
#  </div>
#  <div class="incr_dcr">
#  <span class="per greenTxt">48.85 (0.26%)</span>
#  </div>
#  </div>
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>,
#  <div class="mkt_widget">
#  <div class="widget_head" id="marketStat0">
#  <div class="index_val">
#  <span class="val ltp">18,609.35
#                                                  <i class="fa fa-caret-up cool-green"></i>
#  </span>
#  </div>
#  <div class="incr_dcr">
#  <span class="per greenTxt">48.85 (0.26%)</span>
#  </div>
#  </div>
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>,
#  <div class="widget_head" id="marketStat0">
#  <div class="index_val">
#  <span class="val ltp">18,609.35
#                                                  <i class="fa fa-caret-up cool-green"></i>
#  </span>
#  </div>
#  <div class="incr_dcr">
#  <span class="per greenTxt">48.85 (0.26%)</span>
#  </div>
#  </div>,
#  <div class="index_val">
#  <span class="val ltp">18,609.35
#                                                  <i class="fa fa-caret-up cool-green"></i>
#  </span>
#  </div>,
#  <div class="incr_dcr">
#  <span class="per greenTxt">48.85 (0.26%)</span>
#  </div>,
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>,
#  <div aria-hidden="true" class="form-inline niftyFifty slick-slide" data-slick-index="1" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="currencyLogo">
#  <img alt="NSE - Currency Derivative" src="/assets/images/logo_currencyDer.png" title="NSE - Currency Derivative"/>
#  </figure>
#  <p class="redTxt">Currency Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="logo_with_text">
#  <figure class="currencyLogo">
#  <img alt="NSE - Currency Derivative" src="/assets/images/logo_currencyDer.png" title="NSE - Currency Derivative"/>
#  </figure>
#  <p class="redTxt">Currency Market is Closed</p>
#  </div>,
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>,
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>,
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>,
#  <div aria-hidden="true" class="form-inline niftyFifty slick-slide" data-slick-index="2" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Commodity Derivative" src="/assets/images/logo_commodityDer.png" title="NSE - Commodity Derivative"/>
#  </figure>
#  <p class="greenTxt">Commodity Market is Open</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Current
#                                              Trading Date - 08-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Commodity Derivative" src="/assets/images/logo_commodityDer.png" title="NSE - Commodity Derivative"/>
#  </figure>
#  <p class="greenTxt">Commodity Market is Open</p>
#  </div>,
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Current
#                                              Trading Date - 08-Dec-2022</p>
#  </div>
#  </div>
#  </div>,
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Current
#                                              Trading Date - 08-Dec-2022</p>
#  </div>
#  </div>,
#  <div class="widget_body">
#  <p class="next_date">Current
#                                              Trading Date - 08-Dec-2022</p>
#  </div>,
#  <div aria-hidden="true" class="form-inline niftyFifty slick-slide" data-slick-index="3" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="logo_with_text">
#  <figure class="commodityLogo">
#  <img alt="NSE - Debt Market" src="/assets/images/nse-debt-market-logo.png" title="NSE - Debt Market"/>
#  </figure>
#  <p class="redTxt">Debt Market is Closed</p>
#  </div>,
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>,
#  <div class="mkt_widget">
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>,
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>,
#  <div aria-hidden="true" class="form-inline niftyFifty slick-slide slick-cloned" data-slick-index="4" id="" style="width: 331px;">
#  <div class="logo_with_text">
#  <figure class="capitalLogo">
#  <img alt="NSE - NIFTY 50" src="/assets/images/logo_nifty50.png" title="NSE - NIFTY 50"/>
#  </figure>
#  <p class="redTxt" id="">Normal Market has Closed</p>
#  </div>
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_head" id="">
#  <div class="index_val">
#  <span class="val ltp">18,609.35
#                                                  <i class="fa fa-caret-up cool-green"></i>
#  </span>
#  </div>
#  <div class="incr_dcr">
#  <span class="per greenTxt">48.85 (0.26%)</span>
#  </div>
#  </div>
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="logo_with_text">
#  <figure class="capitalLogo">
#  <img alt="NSE - NIFTY 50" src="/assets/images/logo_nifty50.png" title="NSE - NIFTY 50"/>
#  </figure>
#  <p class="redTxt" id="">Normal Market has Closed</p>
#  </div>,
#  <div class="head-carousel">
#  <div class="mkt_widget">
#  <div class="widget_head" id="">
#  <div class="index_val">
#  <span class="val ltp">18,609.35
#                                                  <i class="fa fa-caret-up cool-green"></i>
#  </span>
#  </div>
#  <div class="incr_dcr">
#  <span class="per greenTxt">48.85 (0.26%)</span>
#  </div>
#  </div>
#  <div class="widget_body">
#  <p class="next_date">Next
#                                              Trading Date - 09-Dec-2022</p>
#  </div>
#  </div>
#  </div>,
#  <div class="mkt_widget">
#  <div class="widget_head" id="">
#  <div class="index_val">
#  <span class="val ltp">18,609.35
#                                                  <i class="fa fa-caret-up cool-green"></i>
#  </span>
#  </div>
#  <div class="incr_dcr">
#  <span class="per greenTxt">48.85 (0.26%)</span>
#  </div>
#  </div>
# ...
#  </div>
#  <div class="col-md-6 col-6 text-right">
#  <div class="link-view-all text-right">
#  <a href="/all-reports-derivatives">Customize Reports for Download <img alt="View All" height="10" src="/assets/images/Read_more_CTA.svg" title="View All" width="14"/></a>
#  </div>
#  </div>
#  </div>
#  <div class="row my-3" id="QLDerivativeMarket">
#  </div>
#  </div>
#  </div>
#  <div class="tab-pane fade" id="qinvest_debt_mr" role="tabpanel">
#  <div class="shadow-box withpadding round-border">
#  <div class="row align-items-center mt-3 mb-4">
#  <div class="col-md-6 col-6" id="QLDebtMarket_SelectAll">
#  <label aria-checked="false" aria-label="Select All Reports" class="chk_container selectAll" data-container="QLDebtMarket" role="checkbox" tabindex="0">Select All Reports
#                                                          <input type="checkbox"/>
#  <span class="checkmark"></span>
#  </label>
#  <a class="link ml-4" href="javascript:;" onclick="downloadReports('#QLDebtMarket', 'daily')"> Multiple file Download <i class="fa fa-download"></i></a>
#  </div>
#  <div class="col-md-6 col-6 text-right">
#  <div class="link-view-all text-right">
#  <a href="/all-reports-debt">Customize Reports for Download <img alt="View All" height="10" src="/assets/images/Read_more_CTA.svg" title="View All" width="14"/></a>
#  </div>
#  </div>
#  </div>
#  <div class="row my-3" id="QLDebtMarket">
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4" style="">
#  <div class="mktsnapshot_section" id="qlMarketStatus" style="">
#  <div class="card shadow-box" style="">
#  <div class="card-header">
#  <div class="row">
#  <div class="col-md-7">
#  <h4 id="market-snapshot">Market Snapshot</h4>
#  <p class="m-0"><span class="asondate">As on <span></span> IST</span></p>
#  </div>
#  <div class="col-md-5">
#  <div class="link-view-all text-right">
#  <a href="/market-data/analysis-and-tools-capital-market-snapshot">View Details <img alt="View All" height="10" src="/assets/images/Read_more_CTA.svg" title="View All" width="14"/></a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="card-body" style="">
#  <div class="mkt_updown">
#  <label class="m-0">NIFTY50</label>
#  <div class="content">
#  <span class="val">-</span>
#  <span class="arrow arrow-up-green"><span class="invisibleText">High</span></span>
#  <span class="val_per">-</span>
#  </div>
#  </div>
#  <hr class="m-edge"/>
#  <div class="stats_ochl">
#  <div class="row">
#  <div class="col-md-3 col-sm-3 col-3">
#  <label>Open</label>
#  <p id="qlopen">-</p>
#  </div>
#  <div class="col-md-3 col-sm-3 col-3">
#  <label>High</label>
#  <p id="qlhigh">-</p>
#  </div>
#  <div class="col-md-3 col-sm-3 col-3">
#  <label>Low</label>
#  <p id="qllow">-</p>
#  </div>
#  <div class="col-md-3 col-sm-3 col-3">
#  <label>Close</label>
#  <p id="qlclose">-</p>
#  </div>
#  </div>
#  </div>
#  <hr class="m-edge"/>
#  <div class="stats_ochl">
#  <div class="row">
#  <div class="col-md-4 col-4">
#  <div class="d-flex flex-column">
#  <p class="val_heading">Volume <small>(Lakhs)</small></p>
#  <p class="mkt_val" id="qlvolume"></p>
#  </div>
#  </div>
#  <div class="col-md-4 col-4">
#  <div class="d-flex flex-column">
#  <p class="val_heading">Value <small>(Lakhs)</small></p>
#  <p class="mkt_val" id="qlvalue"></p>
#  </div>
#  </div>
#  <div class="col-md-4 col-4">
#  <div class="d-flex flex-column">
#  <p class="val_heading" title="Free Float Market Capitalization (in Rs. Lakhs)">FFM .Cap <small>(Lakhs)</small></p>
#  <p class="mkt_val" id="qlffmc"></p>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!--<div class="volval">
#                                                  <ul>
#                                                      <li><label>Volume <small>(Shares)</small> -</label> <span id="qlvolume"> </span></li>
#                                                      <li><Label>Value -</Label> <span id="qlvalue">-</span></li>
#                                                      <li><label>Free float market capitalization -</label> <span id="qlffmc"></span></li>
#                                                  </ul>
#                                              </div>-->
#  <div class="mktslider mt-2" style="">
#  <div class="slider_wrap" style="">
#  <div class="rangeslider-wrap" style="">
#  <input aria-labelledby="market-snapshot" aria-orientation="horizontal" aria-valuemax="300.00" aria-valuemin="283.50" aria-valuenow="285" id="qlrangeslider2" max="300.00" min="283.50" step="0.05" style="position: absolute; width: 1px; height: 1px; overflow: hidden; opacity: 0;" type="range" value="285"/><div class="rangeslider rangeslider--horizontal rangeslider--disabled" id="js-rangeslider-0" style=""><div class="rangeslider__fill" style="width: 24.7273px;"></div><div class="rangeslider__handle" style="left: 23.7273px;"></div><div class="rangeslider_fix" style="position: absolute; left: 23.7273px; display: none;">|</div><div class="rangeslider__handle__value" style="left: 23px;">285.00</div></div>
#  </div>
#  </div>
#  <div class="labels">
#  <label class="left m-0 mr-auto" id="qlwhlMin">- <small>-</small></label>
#  <label class="right m-0 ml-auto" id="qlwhlMax"><small>-</small> -</label>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-md-8">
#  <nav class="text-uppercase border-0">
#  <div class="nav nav-tabs" role="tablist"> <a aria-selected="true" class="nav-item nav-link active" data-toggle="tab" href="#qinvest_equity_mr" role="tab">Equity Market Report</a>
#  <a aria-selected="false" class="nav-item nav-link" data-toggle="tab" href="#qinvest_deriv_mr" role="tab">Derivatives Market Report</a>
#  <a aria-selected="false" class="nav-item nav-link" data-toggle="tab" href="#qinvest_debt_mr" role="tab">Debt Market Report</a>
#  </div>
#  </nav>
#  <div class="tab-content">
#  <div class="tab-pane fade show active" id="qinvest_equity_mr" role="tabpanel">
#  <div class="shadow-box withpadding round-border">
#  <div class="row align-items-center mt-3 mb-4">
#  <div class="col-md-6 col-6" id="QLEquityMarket_SelectAll">
#  <label aria-label="Select All Reports" class="chk_container selectAll" data-container="QLEquityMarket" tabindex="0">Select All Reports
#                                                          <input type="checkbox"/>
#  <span class="checkmark"></span>
#  </label>
#  <a class="link ml-4" href="javascript:;" onclick="downloadReports('#QLEquityMarket', 'daily')"> Multiple file Download <i class="fa fa-download"></i></a>
#  </div>
#  <div class="col-md-6 col-6 text-right">
#  <div class="link-view-all text-right">
#  <a href="/all-reports">Customize Reports for Download <img alt="View All" height="10" src="/assets/images/Read_more_CTA.svg" title="View All" width="14"/></a>
#  </div>
#  </div>
#  </div>
#  <div class="row my-3" id="QLEquityMarket">
#  </div>
#  </div>
#  </div>
#  <div class="tab-pane fade" id="qinvest_deriv_mr" role="tabpanel">
#  <div class="shadow-box withpadding round-border">
#  <div class="row align-items-center mt-3 mb-4">
#  <div class="col-md-6 col-6" id="QLEquityMarket_SelectAll2">
#  <label aria-checked="false" aria-label="Select All Reports" class="chk_container selectAll" data-container="QLDerivativeMarket" id="selectAllQL" role="checkbox" tabindex="0">Select All Reports
#                                                          <input type="checkbox"/>
#  <span class="checkmark"></span>
#  </label>
#  <a class="link ml-4" href="javascript:;" onclick="downloadReports('#QLDerivativeMarket', 'daily')"> Multiple file Download <i class="fa fa-download"></i></a>
#  </div>
#  <div class="col-md-6 col-6 text-right">
#  <div class="link-view-all text-right">
#  <a href="/all-reports-derivatives">Customize Reports for Download <img alt="View All" height="10" src="/assets/images/Read_more_CTA.svg" title="View All" width="14"/></a>
#  </div>
#  </div>
#  </div>
#  <div class="row my-3" id="QLDerivativeMarket">
#  </div>
#  </div>
#  </div>
#  <div class="tab-pane fade" id="qinvest_debt_mr" role="tabpanel">
#  <div class="shadow-box withpadding round-border">
#  <div class="row align-items-center mt-3 mb-4">
#  <div class="col-md-6 col-6" id="QLDebtMarket_SelectAll">
#  <label aria-checked="false" aria-label="Select All Reports" class="chk_container selectAll" data-container="QLDebtMarket" role="checkbox" tabindex="0">Select All Reports
#                                                          <input type="checkbox"/>
#  <span class="checkmark"></span>
#  </label>
#  <a class="link ml-4" href="javascript:;" onclick="downloadReports('#QLDebtMarket', 'daily')"> Multiple file Download <i class="fa fa-download"></i></a>
#  </div>
#  <div class="col-md-6 col-6 text-right">
#  <div class="link-view-all text-right">
#  <a href="/all-reports-debt">Customize Reports for Download <img alt="View All" height="10" src="/assets/images/Read_more_CTA.svg" title="View All" width="14"/></a>
#  </div>
#  </div>
#  </div>
#  <div class="row my-3" id="QLDebtMarket">
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="nav nav-tabs" role="tablist"> <a aria-selected="true" class="nav-item nav-link active" data-toggle="tab" href="#qinvest_equity_mr" role="tab">Equity Market Report</a>
#  <a aria-selected="false" class="nav-item nav-link" data-toggle="tab" href="#qinvest_deriv_mr" role="tab">Derivatives Market Report</a>
#  <a aria-selected="false" class="nav-item nav-link" data-toggle="tab" href="#qinvest_debt_mr" role="tab">Debt Market Report</a>
#  </div>,
#  <div class="tab-content">
#  <div class="tab-pane fade show active" id="qinvest_equity_mr" role="tabpanel">
#  <div class="shadow-box withpadding round-border">
#  <div class="row align-items-center mt-3 mb-4">
#  <div class="col-md-6 col-6" id="QLEquityMarket_SelectAll">
#  <label aria-label="Select All Reports" class="chk_container selectAll" data-container="QLEquityMarket" tabindex="0">Select All Reports
#                                                          <input type="checkbox"/>
#  <span class="checkmark"></span>
#  </label>
#  <a class="link ml-4" href="javascript:;" onclick="downloadReports('#QLEquityMarket', 'daily')"> Multiple file Download <i class="fa fa-download"></i></a>
#  </div>
#  <div class="col-md-6 col-6 text-right">
#  <div class="link-view-all text-right">
#  <a href="/all-reports">Customize Reports for Download <img alt="View All" height="10" src="/assets/images/Read_more_CTA.svg" title="View All" width="14"/></a>
#  </div>
#  </div>
#  </div>
#  <div class="row my-3" id="QLEquityMarket">
#  </div>
#  </div>
#  </div>
#  <div class="tab-pane fade" id="qinvest_deriv_mr" role="tabpanel">
#  <div class="shadow-box withpadding round-border">
#  <div class="row align-items-center mt-3 mb-4">
#  <div class="col-md-6 col-6" id="QLEquityMarket_SelectAll2">
#  <label aria-checked="false" aria-label="Select All Reports" class="chk_container selectAll" data-container="QLDerivativeMarket" id="selectAllQL" role="checkbox" tabindex="0">Select All Reports
#                                                          <input type="checkbox"/>
#  <span class="checkmark"></span>
#  </label>
#  <a class="link ml-4" href="javascript:;" onclick="downloadReports('#QLDerivativeMarket', 'daily')"> Multiple file Download <i class="fa fa-download"></i></a>
#  </div>
#  <div class="col-md-6 col-6 text-right">
#  <div class="link-view-all text-right">
#  <a href="/all-reports-derivatives">Customize Reports for Download <img alt="View All" height="10" src="/assets/images/Read_more_CTA.svg" title="View All" width="14"/></a>
#  </div>
#  </div>
#  </div>
#  <div class="row my-3" id="QLDerivativeMarket">
#  </div>
#  </div>
#  </div>
#  <div class="tab-pane fade" id="qinvest_debt_mr" role="tabpanel">
#  <div class="shadow-box withpadding round-border">
#  <div class="row align-items-center mt-3 mb-4">
#  <div class="col-md-6 col-6" id="QLDebtMarket_SelectAll">
#  <label aria-checked="false" aria-label="Select All Reports" class="chk_container selectAll" data-container="QLDebtMarket" role="checkbox" tabindex="0">Select All Reports
#                                                          <input type="checkbox"/>
#  <span class="checkmark"></span>
#  </label>
#  <a class="link ml-4" href="javascript:;" onclick="downloadReports('#QLDebtMarket', 'daily')"> Multiple file Download <i class="fa fa-download"></i></a>
#  </div>
#  <div class="col-md-6 col-6 text-right">
#  <div class="link-view-all text-right">
#  <a href="/all-reports-debt">Customize Reports for Download <img alt="View All" height="10" src="/assets/images/Read_more_CTA.svg" title="View All" width="14"/></a>
#  </div>
#  </div>
#  </div>
#  <div class="row my-3" id="QLDebtMarket">
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="tab-pane fade show active" id="qinvest_equity_mr" role="tabpanel">
#  <div class="shadow-box withpadding round-border">
#  <div class="row align-items-center mt-3 mb-4">
#  <div class="col-md-6 col-6" id="QLEquityMarket_SelectAll">
#  <label aria-label="Select All Reports" class="chk_container selectAll" data-container="QLEquityMarket" tabindex="0">Select All Reports
#                                                          <input type="checkbox"/>
#  <span class="checkmark"></span>
#  </label>
#  <a class="link ml-4" href="javascript:;" onclick="downloadReports('#QLEquityMarket', 'daily')"> Multiple file Download <i class="fa fa-download"></i></a>
#  </div>
#  <div class="col-md-6 col-6 text-right">
#  <div class="link-view-all text-right">
#  <a href="/all-reports">Customize Reports for Download <img alt="View All" height="10" src="/assets/images/Read_more_CTA.svg" title="View All" width="14"/></a>
#  </div>
#  </div>
#  </div>
#  <div class="row my-3" id="QLEquityMarket">
#  </div>
#  </div>
#  </div>,
#  <div class="shadow-box withpadding round-border">
#  <div class="row align-items-center mt-3 mb-4">
#  <div class="col-md-6 col-6" id="QLEquityMarket_SelectAll">
#  <label aria-label="Select All Reports" class="chk_container selectAll" data-container="QLEquityMarket" tabindex="0">Select All Reports
#                                                          <input type="checkbox"/>
#  <span class="checkmark"></span>
#  </label>
#  <a class="link ml-4" href="javascript:;" onclick="downloadReports('#QLEquityMarket', 'daily')"> Multiple file Download <i class="fa fa-download"></i></a>
#  </div>
#  <div class="col-md-6 col-6 text-right">
#  <div class="link-view-all text-right">
#  <a href="/all-reports">Customize Reports for Download <img alt="View All" height="10" src="/assets/images/Read_more_CTA.svg" title="View All" width="14"/></a>
#  </div>
#  </div>
#  </div>
#  <div class="row my-3" id="QLEquityMarket">
#  </div>
#  </div>,
#  <div class="row align-items-center mt-3 mb-4">
#  <div class="col-md-6 col-6" id="QLEquityMarket_SelectAll">
#  <label aria-label="Select All Reports" class="chk_container selectAll" data-container="QLEquityMarket" tabindex="0">Select All Reports
#                                                          <input type="checkbox"/>
#  <span class="checkmark"></span>
#  </label>
#  <a class="link ml-4" href="javascript:;" onclick="downloadReports('#QLEquityMarket', 'daily')"> Multiple file Download <i class="fa fa-download"></i></a>
#  </div>
#  <div class="col-md-6 col-6 text-right">
#  <div class="link-view-all text-right">
#  <a href="/all-reports">Customize Reports for Download <img alt="View All" height="10" src="/assets/images/Read_more_CTA.svg" title="View All" width="14"/></a>
#  </div>
#  </div>
#  </div>,
#  <div class="col-md-6 col-6" id="QLEquityMarket_SelectAll">
#  <label aria-label="Select All Reports" class="chk_container selectAll" data-container="QLEquityMarket" tabindex="0">Select All Reports
#                                                          <input type="checkbox"/>
#  <span class="checkmark"></span>
#  </label>
#  <a class="link ml-4" href="javascript:;" onclick="downloadReports('#QLEquityMarket', 'daily')"> Multiple file Download <i class="fa fa-download"></i></a>
#  </div>,
#  <div class="col-md-6 col-6 text-right">
#  <div class="link-view-all text-right">
#  <a href="/all-reports">Customize Reports for Download <img alt="View All" height="10" src="/assets/images/Read_more_CTA.svg" title="View All" width="14"/></a>
#  </div>
#  </div>,
#  <div class="link-view-all text-right">
#  <a href="/all-reports">Customize Reports for Download <img alt="View All" height="10" src="/assets/images/Read_more_CTA.svg" title="View All" width="14"/></a>
#  </div>,
#  <div class="row my-3" id="QLEquityMarket">
#  </div>,
#  ...]

# %%
t = soup.body
for T in t.find_all('div'):
    print(T.text)
# Out:
# YOU ARE ON THE NEW NSE WEBSITE, ACCESS THE OLD WEBSITE ON THE URL www1.nseindia.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Normal Market has Closed
#
#
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Currency Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Commodity Market is Open
#
#
#
#
# Current
#                                             Trading Date - 08-Dec-2022
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Normal Market has Closed
#
#
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Currency Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Commodity Market is Open
#
#
#
#
# Current
#                                             Trading Date - 08-Dec-2022
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Normal Market has Closed
#
#
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Currency Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Commodity Market is Open
#
#
#
#
# Current
#                                             Trading Date - 08-Dec-2022
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Normal Market has Closed
#
#
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Currency Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Commodity Market is Open
#
#
#
#
# Current
#                                             Trading Date - 08-Dec-2022
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Normal Market has Closed
#
#
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Currency Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Commodity Market is Open
#
#
#
#
# Current
#                                             Trading Date - 08-Dec-2022
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Normal Market has Closed
#
#
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Currency Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Commodity Market is Open
#
#
#
#
# Current
#                                             Trading Date - 08-Dec-2022
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Normal Market has Closed
#
#
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Currency Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Commodity Market is Open
#
#
#
#
# Current
#                                             Trading Date - 08-Dec-2022
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Normal Market has Closed
#
#
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Currency Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Commodity Market is Open
#
#
#
#
# Current
#                                             Trading Date - 08-Dec-2022
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Normal Market has Closed
#
#
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Currency Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Commodity Market is Open
#
#
#
#
# Current
#                                             Trading Date - 08-Dec-2022
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Normal Market has Closed
#
#
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Currency Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Commodity Market is Open
#
#
#
#
# Current
#                                             Trading Date - 08-Dec-2022
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
# Normal Market has Closed
#
#
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Normal Market has Closed
#
#
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
# Currency Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Currency Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
# Commodity Market is Open
#
#
#
#
# Current
#                                             Trading Date - 08-Dec-2022
#
#
#
#
#
#
#
#
# Commodity Market is Open
#
#
#
#
# Current
#                                             Trading Date - 08-Dec-2022
#
#
#
#
#
# Current
#                                             Trading Date - 08-Dec-2022
#
#
#
# Current
#                                             Trading Date - 08-Dec-2022
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
# Normal Market has Closed
#
#
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Normal Market has Closed
#
#
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
#
# 18,609.35
#
#
#
#
# 48.85 (0.26%)
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
# Currency Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Currency Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
# Commodity Market is Open
#
#
#
#
# Current
#                                             Trading Date - 08-Dec-2022
#
#
#
#
#
#
#
#
# Commodity Market is Open
#
#
#
#
# Current
#                                             Trading Date - 08-Dec-2022
#
#
#
#
#
# Current
#                                             Trading Date - 08-Dec-2022
#
#
#
# Current
#                                             Trading Date - 08-Dec-2022
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
#
#
# Debt Market is Closed
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
# Next
#                                             Trading Date - 09-Dec-2022
#
#
#
#
#
#
# Home
#
#
# About
#
#
#
#
# About NSE
#
#
# About Us
#
#
# Structure & Key Personnel
#
#
# Investor Relations
#
#
# Awards and Recognitions
#
#
# Regulations
#
#
# Event Gallery
#
#
# Media
#
#
# Holidays
#
#
# Careers
#
#
# Contact Us
#
#
#
#
# NSE Group companies
#
#
# NSE Academy
#
#
# NSE Clearing
#
#
# NSE Data & Analytics
#
#
# NSE Foundation
#
#
# NSE Indices
#
#
# NSE International Exchange
#
#
# NSE International Clearing
#
#
# NSE Investments
#
#
# NSEIT
#
#
# View all
#
#
#
#
# Products & Services
#
#
# Equity Market
#
#
# Indices
#
#
# Emerge Platform
#
#
# Mutual Funds
#
#
# Equity Derivatives
#
#
# Currency Derivatives
#
#
# Commodity Derivatives
#
#
# Interest Rate Derivatives
#
#
# Fixed Income and Debt
#
#
# Public Issues
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# About Us
# Find everything about the leading stock exchange of India
#
#
#
#
#
#
#
#
#
# Our Group
# Check NSE's group of the companies
#
#
#
#
#
#
#
#
#
# Our Products
# Browse a comprehensive and innovative product and service offerings by NSE
#
#
#
#
#
#
#
#
#
# Market Data
#
#
#
#
# Market Watch
#
#
# Pre-Open Market
#
#
# Equity & SME Market
#
#
# Derivatives Market
#
#
# Indices
#
#
# Fixed Income & Debt Market
#
#
# Call Auction for Illiquid Securities
#
#
# Securities Lending & Borrowing
#
#
#
#
# Trade Information
#
#
# Securities available for Trading
#
#
# Contracts available for Trading
#
#
# Price Bands & Surveillance Actions
#
#
# Position/Investment Limits
#
#
# Legend of series
#
#
# Liquidity Enhancement Scheme
#
#
# New Listings
#
#
# New Public Issues
#
#
#
#
# Get Market Data
#
#
# Daily Market Reports
#
#
# Paid Real Time Data
#
#
# Paid Analytical Products
#
#
# Paid Non-Display Data
#
#
# Paid Historical Data
#
#
# Paid Corporate Data
#
#
# Paid E-Book
#
#
# NSE Data Sharing & Usage Policy
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Market Snapshot
# Live Analysis of top gainers/losers, most active securities/contracts, price band hitters, overview of the market.
#
#
#
#
#
#
#
#
#
# Option Chain
# View Option chain for the exchange
#
#
#
#
#
#
#
#
#
# Stock Screener
# Screen stocks based on key fundamentals with the NSE Stock Screener to make your investing a more process-driven.
#
#
#
#
#
#
#
#
#
# Invest
#
#
#
#
# First time Investor
#
#
# How to open an Trading account
#
#
# Protection from Fraud
#
#
# Investor Awareness Programs
#
#
# Charges and Taxes
#
#
# Investment limits for FIIs
#
#
# Give Feedback
#
#
#
#
# Resources & Tools
#
#
# Investor Charter
#
#
# Know/ Locate your Stock Broker
#
#
# Company Directory
#
#
# Check Trades/ Bids
#
#
# Exit Option for shareholders
#
#
# Regulatory Actions
#
#
#
#
# Making a Complaint
#
#
# Process
#
#
# File a Complaint Online
#
#
# Download Complaint Form
#
#
# Committees/ Panels
#
#
# Arbitration
#
#
# Defaulter / Expelled Members
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Investor's Home
# Investor education on how to invest safely and protect your investments.
#
#
#
#
#
#
#
#
#
# Product Information
# Browse NSE products under Cash, derivatives, currency derivatives etc.
#
#
#
#
#
#
#
#
#
# Login to NSE NICE Plus
# File and Track your Complaint online.
#
#
#
#
#
#
#
#
#
# List
#
#
#
#
# Raising Capital
#
#
# On-boarding Process
#
#
# Primary Market - Main Board
#
#
# Primary Market - SME
#
#
# Debt - Private Placement
#
#
# Mutual Fund/ETFs
#
#
# Further Issues
#
#
#
#
# Corporate Filings
#
#
# Announcements
#
#
# Board Meetings
#
#
# Corporate Actions
#
#
# Financial Results
#
#
# Shareholding Pattern
#
#
# Offer Documents
#
#
# Scheme of Arrangement
#
#
#
#
# Resources for Listed Companies
#
#
# SEBI Regulations
#
#
# Compliance Information
#
#
# XBRL Information
#
#
# Company Directory
#
#
# Circulars to Listed Companies
#
#
# Social Stock Exchange
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Corporates Home
# Important information, reference material and latest announcements for corporates
#
#
#
#
#
#
#
#
#
# Company Compliance Information
# Status of compliance's under various Regulatory requirements
#
#
#
#
#
#
#
#
#
# NEAPS Portal
# Login for Listed Companies
#
#
#
#
#
#
#
#
#
# Trade
#
#
#
#
# Become a Member
#
#
# Process & FAQs
#
#
# Eligibility Criteria & Categories
#
#
# Fees, Deposits & Networth
#
#
# Using ENIT
#
#
#
#
# Resources for Members
#
#
# Change In Membership
#
#
# Member Compliance
#
#
# Disciplinary Action
#
#
# Format
#
#
#
#
# Platforms & Services
#
#
# NSE Trading Technology
#
#
# NEAT & Non-NEAT Front end
#
#
# Test Market Facility
#
#
# Connectivity & User Id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Member's Home
# Important Information, reference materials and latest announcements for members.
#
#
#
#
#
#
#
#
#
# Member Portal
# ENIT - A Portal for Trading Members of NSE to manage their Membership and Compliance requirements.
#
#
#
#
#
#
#
#
#
# Exchange Communication
# Browse Exchange circulars, press release and media articles.
#
#
#
#
#
#
#
#
#
# Regulation
#
#
#
#
# Exchange
#
#
# Market Rules & Regulations
#
#
# Market Surveillance
#
#
# Exchange Disclosures
#
#
# Defaulting Clients
#
#
# Investor's Beware
#
#
# Submit a Tip-Off
#
#
#
#
# Member
#
#
# Member Compliance
#
#
# Complaint against Members
#
#
# Action against Members
#
#
# Debarred Entities
#
#
# Circulars for Members
#
#
# Public Notice
#
#
#
#
# Corporates
#
#
# Company Compliance
#
#
# Rumour Verification
#
#
# Delisting of Companies
#
#
# Queries raised to Listed Companies
#
#
# Complaint Status against Companies
#
#
# Public Notice
#
#
#
#
#
#
#
#
# Learn
#
#
#
#
# Getting Started
#
#
# About NSE Academy
#
#
# Get started for NCFM
#
#
# Certification Modules
#
#
# How to take a Test
#
#
# Visit To NSE
#
#
#
#
# Courses/Programs
#
#
# Online Interactive Courses
#
#
# Online Recorded Courses
#
#
# Class Room Courses
#
#
# Post Graduate Programs
#
#
# Professional Development Programs
#
#
#
#
# Student Requirement
#
#
# Modules for Under graduates
#
#
# Modules for Dealers
#
#
# Modules for Professionals
#
#
# Self-Study Courses & Certifications
#
#
# Program Calendar
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Find a course
# Click here to find a course
#
#
#
#
#
#
#
#
#
# NSE Knowledge Hub
# Click here to join the platform
#
#
#
#
#
#
#
#
#
# NCFM Login
# NCFM Portal for online testing and certification programmes offered by NSE Academy.
#
#
#
#
#
#
#
#
#
# Resources
#
#
#
#
# Exchange Communication
#
#
# Circulars
#
#
# Press Releases
#
#
# Holidays
#
#
# Contingency Drill
#
#
# Media Center
#
#
#
#
# Downloads
#
#
# Daily Market Reports
#
#
# Historical Reports
#
#
# Forms & Formats
#
#
# Business Growth & Volume
#
#
#
#
# Research Initiatives
#
#
# Working Paper Series
#
#
# Panel Discussions & Seminars
#
#
# Lecture Series
#
#
# Financial Research Initiatives
#
#
# Publications & Reports
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Exchange Communication
# Find all communication issued by the Exchange in this section
#
#
#
#
#
#
#
#
#
# Downloads
# Daily and Archive Reports, Formats and Business Growth download it here
#
#
#
#
#
#
#
#
#
# Research Initiatives
# Homepage for Researchers and Academia to participate in research initiatives
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# About
#
#
#
#
# About NSE
#
#
# About Us
#
#
# Structure & Key Personnel
#
#
# Investor Relations
#
#
# Awards and Recognitions
#
#
# Regulations
#
#
# Event Gallery
#
#
# Media
#
#
# Holidays
#
#
# Careers
#
#
# Contact Us
#
#
#
#
# NSE Group companies
#
#
# NSE Academy
#
#
# NSE Clearing
#
#
# NSE Data & Analytics
#
#
# NSE Foundation
#
#
# NSE Indices
#
#
# NSE International Exchange
#
#
# NSE International Clearing
#
#
# NSE Investments
#
#
# NSEIT
#
#
# View all
#
#
#
#
# Products & Services
#
#
# Equity Market
#
#
# Indices
#
#
# Emerge Platform
#
#
# Mutual Funds
#
#
# Equity Derivatives
#
#
# Currency Derivatives
#
#
# Commodity Derivatives
#
#
# Interest Rate Derivatives
#
#
# Fixed Income and Debt
#
#
# Public Issues
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# About Us
# Find everything about the leading stock exchange of India
#
#
#
#
#
#
#
#
#
# Our Group
# Check NSE's group of the companies
#
#
#
#
#
#
#
#
#
# Our Products
# Browse a comprehensive and innovative product and service offerings by NSE
#
#
#
#
#
#
#
#
#
# Market Data
#
#
#
#
# Market Watch
#
#
# Pre-Open Market
#
#
# Equity & SME Market
#
#
# Derivatives Market
#
#
# Indices
#
#
# Fixed Income & Debt Market
#
#
# Call Auction for Illiquid Securities
#
#
# Securities Lending & Borrowing
#
#
#
#
# Trade Information
#
#
# Securities available for Trading
#
#
# Contracts available for Trading
#
#
# Price Bands & Surveillance Actions
#
#
# Position/Investment Limits
#
#
# Legend of series
#
#
# Liquidity Enhancement Scheme
#
#
# New Listings
#
#
# New Public Issues
#
#
#
#
# Get Market Data
#
#
# Daily Market Reports
#
#
# Paid Real Time Data
#
#
# Paid Analytical Products
#
#
# Paid Non-Display Data
#
#
# Paid Historical Data
#
#
# Paid Corporate Data
#
#
# Paid E-Book
#
#
# NSE Data Sharing & Usage Policy
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Market Snapshot
# Live Analysis of top gainers/losers, most active securities/contracts, price band hitters, overview of the market.
#
#
#
#
#
#
#
#
#
# Option Chain
# View Option chain for the exchange
#
#
#
#
#
#
#
#
#
# Stock Screener
# Screen stocks based on key fundamentals with the NSE Stock Screener to make your investing a more process-driven.
#
#
#
#
#
#
#
#
#
# Invest
#
#
#
#
# First time Investor
#
#
# How to open an Trading account
#
#
# Protection from Fraud
#
#
# Investor Awareness Programs
#
#
# Charges and Taxes
#
#
# Investment limits for FIIs
#
#
# Give Feedback
#
#
#
#
# Resources & Tools
#
#
# Investor Charter
#
#
# Know/ Locate your Stock Broker
#
#
# Company Directory
#
#
# Check Trades/ Bids
#
#
# Exit Option for shareholders
#
#
# Regulatory Actions
#
#
#
#
# Making a Complaint
#
#
# Process
#
#
# File a Complaint Online
#
#
# Download Complaint Form
#
#
# Committees/ Panels
#
#
# Arbitration
#
#
# Defaulter / Expelled Members
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Investor's Home
# Investor education on how to invest safely and protect your investments.
#
#
#
#
#
#
#
#
#
# Product Information
# Browse NSE products under Cash, derivatives, currency derivatives etc.
#
#
#
#
#
#
#
#
#
# Login to NSE NICE Plus
# File and Track your Complaint online.
#
#
#
#
#
#
#
#
#
# List
#
#
#
#
# Raising Capital
#
#
# On-boarding Process
#
#
# Primary Market - Main Board
#
#
# Primary Market - SME
#
#
# Debt - Private Placement
#
#
# Mutual Fund/ETFs
#
#
# Further Issues
#
#
#
#
# Corporate Filings
#
#
# Announcements
#
#
# Board Meetings
#
#
# Corporate Actions
#
#
# Financial Results
#
#
# Shareholding Pattern
#
#
# Offer Documents
#
#
# Scheme of Arrangement
#
#
#
#
# Resources for Listed Companies
#
#
# SEBI Regulations
#
#
# Compliance Information
#
#
# XBRL Information
#
#
# Company Directory
#
#
# Circulars to Listed Companies
#
#
# Social Stock Exchange
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Corporates Home
# Important information, reference material and latest announcements for corporates
#
#
#
#
#
#
#
#
#
# Company Compliance Information
# Status of compliance's under various Regulatory requirements
#
#
#
#
#
#
#
#
#
# NEAPS Portal
# Login for Listed Companies
#
#
#
#
#
#
#
#
#
# Trade
#
#
#
#
# Become a Member
#
#
# Process & FAQs
#
#
# Eligibility Criteria & Categories
#
#
# Fees, Deposits & Networth
#
#
# Using ENIT
#
#
#
#
# Resources for Members
#
#
# Change In Membership
#
#
# Member Compliance
#
#
# Disciplinary Action
#
#
# Format
#
#
#
#
# Platforms & Services
#
#
# NSE Trading Technology
#
#
# NEAT & Non-NEAT Front end
#
#
# Test Market Facility
#
#
# Connectivity & User Id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Member's Home
# Important Information, reference materials and latest announcements for members.
#
#
#
#
#
#
#
#
#
# Member Portal
# ENIT - A Portal for Trading Members of NSE to manage their Membership and Compliance requirements.
#
#
#
#
#
#
#
#
#
# Exchange Communication
# Browse Exchange circulars, press release and media articles.
#
#
#
#
#
#
#
#
#
# Regulation
#
#
#
#
# Exchange
#
#
# Market Rules & Regulations
#
#
# Market Surveillance
#
#
# Exchange Disclosures
#
#
# Defaulting Clients
#
#
# Investor's Beware
#
#
# Submit a Tip-Off
#
#
#
#
# Member
#
#
# Member Compliance
#
#
# Complaint against Members
#
#
# Action against Members
#
#
# Debarred Entities
#
#
# Circulars for Members
#
#
# Public Notice
#
#
#
#
# Corporates
#
#
# Company Compliance
#
#
# Rumour Verification
#
#
# Delisting of Companies
#
#
# Queries raised to Listed Companies
#
#
# Complaint Status against Companies
#
#
# Public Notice
#
#
#
#
#
#
#
#
# Learn
#
#
#
#
# Getting Started
#
#
# About NSE Academy
#
#
# Get started for NCFM
#
#
# Certification Modules
#
#
# How to take a Test
#
#
# Visit To NSE
#
#
#
#
# Courses/Programs
#
#
# Online Interactive Courses
#
#
# Online Recorded Courses
#
#
# Class Room Courses
#
#
# Post Graduate Programs
#
#
# Professional Development Programs
#
#
#
#
# Student Requirement
#
#
# Modules for Under graduates
#
#
# Modules for Dealers
#
#
# Modules for Professionals
#
#
# Self-Study Courses & Certifications
#
#
# Program Calendar
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Find a course
# Click here to find a course
#
#
#
#
#
#
#
#
#
# NSE Knowledge Hub
# Click here to join the platform
#
#
#
#
#
#
#
#
#
# NCFM Login
# NCFM Portal for online testing and certification programmes offered by NSE Academy.
#
#
#
#
#
#
#
#
#
# Resources
#
#
#
#
# Exchange Communication
#
#
# Circulars
#
#
# Press Releases
#
#
# Holidays
#
#
# Contingency Drill
#
#
# Media Center
#
#
#
#
# Downloads
#
#
# Daily Market Reports
#
#
# Historical Reports
#
#
# Forms & Formats
#
#
# Business Growth & Volume
#
#
#
#
# Research Initiatives
#
#
# Working Paper Series
#
#
# Panel Discussions & Seminars
#
#
# Lecture Series
#
#
# Financial Research Initiatives
#
#
# Publications & Reports
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Exchange Communication
# Find all communication issued by the Exchange in this section
#
#
#
#
#
#
#
#
#
# Downloads
# Daily and Archive Reports, Formats and Business Growth download it here
#
#
#
#
#
#
#
#
#
# Research Initiatives
# Homepage for Researchers and Academia to participate in research initiatives
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# About
#
#
#
#
# About NSE
#
#
# About Us
#
#
# Structure & Key Personnel
#
#
# Investor Relations
#
#
# Awards and Recognitions
#
#
# Regulations
#
#
# Event Gallery
#
#
# Media
#
#
# Holidays
#
#
# Careers
#
#
# Contact Us
#
#
#
#
# NSE Group companies
#
#
# NSE Academy
#
#
# NSE Clearing
#
#
# NSE Data & Analytics
#
#
# NSE Foundation
#
#
# NSE Indices
#
#
# NSE International Exchange
#
#
# NSE International Clearing
#
#
# NSE Investments
#
#
# NSEIT
#
#
# View all
#
#
#
#
# Products & Services
#
#
# Equity Market
#
#
# Indices
#
#
# Emerge Platform
#
#
# Mutual Funds
#
#
# Equity Derivatives
#
#
# Currency Derivatives
#
#
# Commodity Derivatives
#
#
# Interest Rate Derivatives
#
#
# Fixed Income and Debt
#
#
# Public Issues
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# About Us
# Find everything about the leading stock exchange of India
#
#
#
#
#
#
#
#
#
# Our Group
# Check NSE's group of the companies
#
#
#
#
#
#
#
#
#
# Our Products
# Browse a comprehensive and innovative product and service offerings by NSE
#
#
#
#
#
#
#
#
#
# Market Data
#
#
#
#
# Market Watch
#
#
# Pre-Open Market
#
#
# Equity & SME Market
#
#
# Derivatives Market
#
#
# Indices
#
#
# Fixed Income & Debt Market
#
#
# Call Auction for Illiquid Securities
#
#
# Securities Lending & Borrowing
#
#
#
#
# Trade Information
#
#
# Securities available for Trading
#
#
# Contracts available for Trading
#
#
# Price Bands & Surveillance Actions
#
#
# Position/Investment Limits
#
#
# Legend of series
#
#
# Liquidity Enhancement Scheme
#
#
# New Listings
#
#
# New Public Issues
#
#
#
#
# Get Market Data
#
#
# Daily Market Reports
#
#
# Paid Real Time Data
#
#
# Paid Analytical Products
#
#
# Paid Non-Display Data
#
#
# Paid Historical Data
#
#
# Paid Corporate Data
#
#
# Paid E-Book
#
#
# NSE Data Sharing & Usage Policy
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Market Snapshot
# Live Analysis of top gainers/losers, most active securities/contracts, price band hitters, overview of the market.
#
#
#
#
#
#
#
#
#
# Option Chain
# View Option chain for the exchange
#
#
#
#
#
#
#
#
#
# Stock Screener
# Screen stocks based on key fundamentals with the NSE Stock Screener to make your investing a more process-driven.
#
#
#
#
#
#
#
#
#
# Invest
#
#
#
#
# First time Investor
#
#
# How to open an Trading account
#
#
# Protection from Fraud
#
#
# Investor Awareness Programs
#
#
# Charges and Taxes
#
#
# Investment limits for FIIs
#
#
# Give Feedback
#
#
#
#
# Resources & Tools
#
#
# Investor Charter
#
#
# Know/ Locate your Stock Broker
#
#
# Company Directory
#
#
# Check Trades/ Bids
#
#
# Exit Option for shareholders
#
#
# Regulatory Actions
#
#
#
#
# Making a Complaint
#
#
# Process
#
#
# File a Complaint Online
#
#
# Download Complaint Form
#
#
# Committees/ Panels
#
#
# Arbitration
#
#
# Defaulter / Expelled Members
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Investor's Home
# Investor education on how to invest safely and protect your investments.
#
#
#
#
#
#
#
#
#
# Product Information
# Browse NSE products under Cash, derivatives, currency derivatives etc.
#
#
#
#
#
#
#
#
#
# Login to NSE NICE Plus
# File and Track your Complaint online.
#
#
#
#
#
#
#
#
#
# List
#
#
#
#
# Raising Capital
#
#
# On-boarding Process
#
#
# Primary Market - Main Board
#
#
# Primary Market - SME
#
#
# Debt - Private Placement
#
#
# Mutual Fund/ETFs
#
#
# Further Issues
#
#
#
#
# Corporate Filings
#
#
# Announcements
#
#
# Board Meetings
#
#
# Corporate Actions
#
#
# Financial Results
#
#
# Shareholding Pattern
#
#
# Offer Documents
#
#
# Scheme of Arrangement
#
#
#
#
# Resources for Listed Companies
#
#
# SEBI Regulations
#
#
# Compliance Information
#
#
# XBRL Information
#
#
# Company Directory
#
#
# Circulars to Listed Companies
#
#
# Social Stock Exchange
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Corporates Home
# Important information, reference material and latest announcements for corporates
#
#
#
#
#
#
#
#
#
# Company Compliance Information
# Status of compliance's under various Regulatory requirements
#
#
#
#
#
#
#
#
#
# NEAPS Portal
# Login for Listed Companies
#
#
#
#
#
#
#
#
#
# Trade
#
#
#
#
# Become a Member
#
#
# Process & FAQs
#
#
# Eligibility Criteria & Categories
#
#
# Fees, Deposits & Networth
#
#
# Using ENIT
#
#
#
#
# Resources for Members
#
#
# Change In Membership
#
#
# Member Compliance
#
#
# Disciplinary Action
#
#
# Format
#
#
#
#
# Platforms & Services
#
#
# NSE Trading Technology
#
#
# NEAT & Non-NEAT Front end
#
#
# Test Market Facility
#
#
# Connectivity & User Id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Member's Home
# Important Information, reference materials and latest announcements for members.
#
#
#
#
#
#
#
#
#
# Member Portal
# ENIT - A Portal for Trading Members of NSE to manage their Membership and Compliance requirements.
#
#
#
#
#
#
#
#
#
# Exchange Communication
# Browse Exchange circulars, press release and media articles.
#
#
#
#
#
#
#
#
#
# Regulation
#
#
#
#
# Exchange
#
#
# Market Rules & Regulations
#
#
# Market Surveillance
#
#
# Exchange Disclosures
#
#
# Defaulting Clients
#
#
# Investor's Beware
#
#
# Submit a Tip-Off
#
#
#
#
# Member
#
#
# Member Compliance
#
#
# Complaint against Members
#
#
# Action against Members
#
#
# Debarred Entities
#
#
# Circulars for Members
#
#
# Public Notice
#
#
#
#
# Corporates
#
#
# Company Compliance
#
#
# Rumour Verification
#
#
# Delisting of Companies
#
#
# Queries raised to Listed Companies
#
#
# Complaint Status against Companies
#
#
# Public Notice
#
#
#
#
#
#
#
#
# Learn
#
#
#
#
# Getting Started
#
#
# About NSE Academy
#
#
# Get started for NCFM
#
#
# Certification Modules
#
#
# How to take a Test
#
#
# Visit To NSE
#
#
#
#
# Courses/Programs
#
#
# Online Interactive Courses
#
#
# Online Recorded Courses
#
#
# Class Room Courses
#
#
# Post Graduate Programs
#
#
# Professional Development Programs
#
#
#
#
# Student Requirement
#
#
# Modules for Under graduates
#
#
# Modules for Dealers
#
#
# Modules for Professionals
#
#
# Self-Study Courses & Certifications
#
#
# Program Calendar
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Find a course
# Click here to find a course
#
#
#
#
#
#
#
#
#
# NSE Knowledge Hub
# Click here to join the platform
#
#
#
#
#
#
#
#
#
# NCFM Login
# NCFM Portal for online testing and certification programmes offered by NSE Academy.
#
#
#
#
#
#
#
#
#
# Resources
#
#
#
#
# Exchange Communication
#
#
# Circulars
#
#
# Press Releases
#
#
# Holidays
#
#
# Contingency Drill
#
#
# Media Center
#
#
#
#
# Downloads
#
#
# Daily Market Reports
#
#
# Historical Reports
#
#
# Forms & Formats
#
#
# Business Growth & Volume
#
#
#
#
# Research Initiatives
#
#
# Working Paper Series
#
#
# Panel Discussions & Seminars
#
#
# Lecture Series
#
#
# Financial Research Initiatives
#
#
# Publications & Reports
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Exchange Communication
# Find all communication issued by the Exchange in this section
#
#
#
#
#
#
#
#
#
# Downloads
# Daily and Archive Reports, Formats and Business Growth download it here
#
#
#
#
#
#
#
#
#
# Research Initiatives
# Homepage for Researchers and Academia to participate in research initiatives
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# About NSE
#
#
# About Us
#
#
# Structure & Key Personnel
#
#
# Investor Relations
#
#
# Awards and Recognitions
#
#
# Regulations
#
#
# Event Gallery
#
#
# Media
#
#
# Holidays
#
#
# Careers
#
#
# Contact Us
#
#
#
#
# NSE Group companies
#
#
# NSE Academy
#
#
# NSE Clearing
#
#
# NSE Data & Analytics
#
#
# NSE Foundation
#
#
# NSE Indices
#
#
# NSE International Exchange
#
#
# NSE International Clearing
#
#
# NSE Investments
#
#
# NSEIT
#
#
# View all
#
#
#
#
# Products & Services
#
#
# Equity Market
#
#
# Indices
#
#
# Emerge Platform
#
#
# Mutual Funds
#
#
# Equity Derivatives
#
#
# Currency Derivatives
#
#
# Commodity Derivatives
#
#
# Interest Rate Derivatives
#
#
# Fixed Income and Debt
#
#
# Public Issues
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# About Us
# Find everything about the leading stock exchange of India
#
#
#
#
#
#
#
#
#
# Our Group
# Check NSE's group of the companies
#
#
#
#
#
#
#
#
#
# Our Products
# Browse a comprehensive and innovative product and service offerings by NSE
#
#
#
#
#
#
#
#
#
#
# About NSE
#
#
# About Us
#
#
# Structure & Key Personnel
#
#
# Investor Relations
#
#
# Awards and Recognitions
#
#
# Regulations
#
#
# Event Gallery
#
#
# Media
#
#
# Holidays
#
#
# Careers
#
#
# Contact Us
#
#
#
#
# NSE Group companies
#
#
# NSE Academy
#
#
# NSE Clearing
#
#
# NSE Data & Analytics
#
#
# NSE Foundation
#
#
# NSE Indices
#
#
# NSE International Exchange
#
#
# NSE International Clearing
#
#
# NSE Investments
#
#
# NSEIT
#
#
# View all
#
#
#
#
# Products & Services
#
#
# Equity Market
#
#
# Indices
#
#
# Emerge Platform
#
#
# Mutual Funds
#
#
# Equity Derivatives
#
#
# Currency Derivatives
#
#
# Commodity Derivatives
#
#
# Interest Rate Derivatives
#
#
# Fixed Income and Debt
#
#
# Public Issues
#
#
#
#
#
#
#
# About NSE
#
#
# About Us
#
#
# Structure & Key Personnel
#
#
# Investor Relations
#
#
# Awards and Recognitions
#
#
# Regulations
#
#
# Event Gallery
#
#
# Media
#
#
# Holidays
#
#
# Careers
#
#
# Contact Us
#
#
#
#
# NSE Group companies
#
#
# NSE Academy
#
#
# NSE Clearing
#
#
# NSE Data & Analytics
#
#
# NSE Foundation
#
#
# NSE Indices
#
#
# NSE International Exchange
#
#
# NSE International Clearing
#
#
# NSE Investments
#
#
# NSEIT
#
#
# View all
#
#
#
#
# Products & Services
#
#
# Equity Market
#
#
# Indices
#
#
# Emerge Platform
#
#
# Mutual Funds
#
#
# Equity Derivatives
#
#
# Currency Derivatives
#
#
# Commodity Derivatives
#
#
# Interest Rate Derivatives
#
#
# Fixed Income and Debt
#
#
# Public Issues
#
#
#
#
#
# About NSE
#
#
# About Us
#
#
# Structure & Key Personnel
#
#
# Investor Relations
#
#
# Awards and Recognitions
#
#
# Regulations
#
#
# Event Gallery
#
#
# Media
#
#
# Holidays
#
#
# Careers
#
#
# Contact Us
#
#
#
#
# NSE Group companies
#
#
# NSE Academy
#
#
# NSE Clearing
#
#
# NSE Data & Analytics
#
#
# NSE Foundation
#
#
# NSE Indices
#
#
# NSE International Exchange
#
#
# NSE International Clearing
#
#
# NSE Investments
#
#
# NSEIT
#
#
# View all
#
#
#
#
# Products & Services
#
#
# Equity Market
#
#
# Indices
#
#
# Emerge Platform
#
#
# Mutual Funds
#
#
# Equity Derivatives
#
#
# Currency Derivatives
#
#
# Commodity Derivatives
#
#
# Interest Rate Derivatives
#
#
# Fixed Income and Debt
#
#
# Public Issues
#
#
#
#
#
#
#
#
#
#
#
#
# About Us
# Find everything about the leading stock exchange of India
#
#
#
#
#
#
#
#
#
# Our Group
# Check NSE's group of the companies
#
#
#
#
#
#
#
#
#
# Our Products
# Browse a comprehensive and innovative product and service offerings by NSE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# About Us
# Find everything about the leading stock exchange of India
#
#
#
#
#
#
#
#
#
# Our Group
# Check NSE's group of the companies
#
#
#
#
#
#
#
#
#
# Our Products
# Browse a comprehensive and innovative product and service offerings by NSE
#
#
#
#
#
#
#
#
#
#
#
#
# About Us
# Find everything about the leading stock exchange of India
#
#
#
#
#
#
#
#
#
# Our Group
# Check NSE's group of the companies
#
#
#
#
#
#
#
#
#
# Our Products
# Browse a comprehensive and innovative product and service offerings by NSE
#
#
#
#
#
#
#
#
#
#
# About Us
# Find everything about the leading stock exchange of India
#
#
#
#
#
#
#
#
# About Us
# Find everything about the leading stock exchange of India
#
#
#
#
#
#
#
#
# Our Group
# Check NSE's group of the companies
#
#
#
#
#
#
#
#
# Our Group
# Check NSE's group of the companies
#
#
#
#
#
#
#
#
# Our Products
# Browse a comprehensive and innovative product and service offerings by NSE
#
#
#
#
#
#
#
#
# Our Products
# Browse a comprehensive and innovative product and service offerings by NSE
#
#
#
#
#
#
# Market Watch
#
#
# Pre-Open Market
#
#
# Equity & SME Market
#
#
# Derivatives Market
#
#
# Indices
#
#
# Fixed Income & Debt Market
#
#
# Call Auction for Illiquid Securities
#
#
# Securities Lending & Borrowing
#
#
#
#
# Trade Information
#
#
# Securities available for Trading
#
#
# Contracts available for Trading
#
#
# Price Bands & Surveillance Actions
#
#
# Position/Investment Limits
#
#
# Legend of series
#
#
# Liquidity Enhancement Scheme
#
#
# New Listings
#
#
# New Public Issues
#
#
#
#
# Get Market Data
#
#
# Daily Market Reports
#
#
# Paid Real Time Data
#
#
# Paid Analytical Products
#
#
# Paid Non-Display Data
#
#
# Paid Historical Data
#
#
# Paid Corporate Data
#
#
# Paid E-Book
#
#
# NSE Data Sharing & Usage Policy
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Market Snapshot
# Live Analysis of top gainers/losers, most active securities/contracts, price band hitters, overview of the market.
#
#
#
#
#
#
#
#
#
# Option Chain
# View Option chain for the exchange
#
#
#
#
#
#
#
#
#
# Stock Screener
# Screen stocks based on key fundamentals with the NSE Stock Screener to make your investing a more process-driven.
#
#
#
#
#
#
#
#
#
#
# Market Watch
#
#
# Pre-Open Market
#
#
# Equity & SME Market
#
#
# Derivatives Market
#
#
# Indices
#
#
# Fixed Income & Debt Market
#
#
# Call Auction for Illiquid Securities
#
#
# Securities Lending & Borrowing
#
#
#
#
# Trade Information
#
#
# Securities available for Trading
#
#
# Contracts available for Trading
#
#
# Price Bands & Surveillance Actions
#
#
# Position/Investment Limits
#
#
# Legend of series
#
#
# Liquidity Enhancement Scheme
#
#
# New Listings
#
#
# New Public Issues
#
#
#
#
# Get Market Data
#
#
# Daily Market Reports
#
#
# Paid Real Time Data
#
#
# Paid Analytical Products
#
#
# Paid Non-Display Data
#
#
# Paid Historical Data
#
#
# Paid Corporate Data
#
#
# Paid E-Book
#
#
# NSE Data Sharing & Usage Policy
#
#
#
#
#
#
#
# Market Watch
#
#
# Pre-Open Market
#
#
# Equity & SME Market
#
#
# Derivatives Market
#
#
# Indices
#
#
# Fixed Income & Debt Market
#
#
# Call Auction for Illiquid Securities
#
#
# Securities Lending & Borrowing
#
#
#
#
# Trade Information
#
#
# Securities available for Trading
#
#
# Contracts available for Trading
#
#
# Price Bands & Surveillance Actions
#
#
# Position/Investment Limits
#
#
# Legend of series
#
#
# Liquidity Enhancement Scheme
#
#
# New Listings
#
#
# New Public Issues
#
#
#
#
# Get Market Data
#
#
# Daily Market Reports
#
#
# Paid Real Time Data
#
#
# Paid Analytical Products
#
#
# Paid Non-Display Data
#
#
# Paid Historical Data
#
#
# Paid Corporate Data
#
#
# Paid E-Book
#
#
# NSE Data Sharing & Usage Policy
#
#
#
#
#
# Market Watch
#
#
# Pre-Open Market
#
#
# Equity & SME Market
#
#
# Derivatives Market
#
#
# Indices
#
#
# Fixed Income & Debt Market
#
#
# Call Auction for Illiquid Securities
#
#
# Securities Lending & Borrowing
#
#
#
#
# Trade Information
#
#
# Securities available for Trading
#
#
# Contracts available for Trading
#
#
# Price Bands & Surveillance Actions
#
#
# Position/Investment Limits
#
#
# Legend of series
#
#
# Liquidity Enhancement Scheme
#
#
# New Listings
#
#
# New Public Issues
#
#
#
#
# Get Market Data
#
#
# Daily Market Reports
#
#
# Paid Real Time Data
#
#
# Paid Analytical Products
#
#
# Paid Non-Display Data
#
#
# Paid Historical Data
#
#
# Paid Corporate Data
#
#
# Paid E-Book
#
#
# NSE Data Sharing & Usage Policy
#
#
#
#
#
#
#
#
#
#
#
#
# Market Snapshot
# Live Analysis of top gainers/losers, most active securities/contracts, price band hitters, overview of the market.
#
#
#
#
#
#
#
#
#
# Option Chain
# View Option chain for the exchange
#
#
#
#
#
#
#
#
#
# Stock Screener
# Screen stocks based on key fundamentals with the NSE Stock Screener to make your investing a more process-driven.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Market Snapshot
# Live Analysis of top gainers/losers, most active securities/contracts, price band hitters, overview of the market.
#
#
#
#
#
#
#
#
#
# Option Chain
# View Option chain for the exchange
#
#
#
#
#
#
#
#
#
# Stock Screener
# Screen stocks based on key fundamentals with the NSE Stock Screener to make your investing a more process-driven.
#
#
#
#
#
#
#
#
#
#
#
#
# Market Snapshot
# Live Analysis of top gainers/losers, most active securities/contracts, price band hitters, overview of the market.
#
#
#
#
#
#
#
#
#
# Option Chain
# View Option chain for the exchange
#
#
#
#
#
#
#
#
#
# Stock Screener
# Screen stocks based on key fundamentals with the NSE Stock Screener to make your investing a more process-driven.
#
#
#
#
#
#
#
#
#
#
# Market Snapshot
# Live Analysis of top gainers/losers, most active securities/contracts, price band hitters, overview of the market.
#
#
#
#
#
#
#
#
# Market Snapshot
# Live Analysis of top gainers/losers, most active securities/contracts, price band hitters, overview of the market.
#
#
#
#
#
#
#
#
# Option Chain
# View Option chain for the exchange
#
#
#
#
#
#
#
#
# Option Chain
# View Option chain for the exchange
#
#
#
#
#
#
#
#
# Stock Screener
# Screen stocks based on key fundamentals with the NSE Stock Screener to make your investing a more process-driven.
#
#
#
#
#
#
#
#
# Stock Screener
# Screen stocks based on key fundamentals with the NSE Stock Screener to make your investing a more process-driven.
#
#
#
#
#
#
# First time Investor
#
#
# How to open an Trading account
#
#
# Protection from Fraud
#
#
# Investor Awareness Programs
#
#
# Charges and Taxes
#
#
# Investment limits for FIIs
#
#
# Give Feedback
#
#
#
#
# Resources & Tools
#
#
# Investor Charter
#
#
# Know/ Locate your Stock Broker
#
#
# Company Directory
#
#
# Check Trades/ Bids
#
#
# Exit Option for shareholders
#
#
# Regulatory Actions
#
#
#
#
# Making a Complaint
#
#
# Process
#
#
# File a Complaint Online
#
#
# Download Complaint Form
#
#
# Committees/ Panels
#
#
# Arbitration
#
#
# Defaulter / Expelled Members
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Investor's Home
# Investor education on how to invest safely and protect your investments.
#
#
#
#
#
#
#
#
#
# Product Information
# Browse NSE products under Cash, derivatives, currency derivatives etc.
#
#
#
#
#
#
#
#
#
# Login to NSE NICE Plus
# File and Track your Complaint online.
#
#
#
#
#
#
#
#
#
#
# First time Investor
#
#
# How to open an Trading account
#
#
# Protection from Fraud
#
#
# Investor Awareness Programs
#
#
# Charges and Taxes
#
#
# Investment limits for FIIs
#
#
# Give Feedback
#
#
#
#
# Resources & Tools
#
#
# Investor Charter
#
#
# Know/ Locate your Stock Broker
#
#
# Company Directory
#
#
# Check Trades/ Bids
#
#
# Exit Option for shareholders
#
#
# Regulatory Actions
#
#
#
#
# Making a Complaint
#
#
# Process
#
#
# File a Complaint Online
#
#
# Download Complaint Form
#
#
# Committees/ Panels
#
#
# Arbitration
#
#
# Defaulter / Expelled Members
#
#
#
#
#
#
#
# First time Investor
#
#
# How to open an Trading account
#
#
# Protection from Fraud
#
#
# Investor Awareness Programs
#
#
# Charges and Taxes
#
#
# Investment limits for FIIs
#
#
# Give Feedback
#
#
#
#
# Resources & Tools
#
#
# Investor Charter
#
#
# Know/ Locate your Stock Broker
#
#
# Company Directory
#
#
# Check Trades/ Bids
#
#
# Exit Option for shareholders
#
#
# Regulatory Actions
#
#
#
#
# Making a Complaint
#
#
# Process
#
#
# File a Complaint Online
#
#
# Download Complaint Form
#
#
# Committees/ Panels
#
#
# Arbitration
#
#
# Defaulter / Expelled Members
#
#
#
#
#
# First time Investor
#
#
# How to open an Trading account
#
#
# Protection from Fraud
#
#
# Investor Awareness Programs
#
#
# Charges and Taxes
#
#
# Investment limits for FIIs
#
#
# Give Feedback
#
#
#
#
# Resources & Tools
#
#
# Investor Charter
#
#
# Know/ Locate your Stock Broker
#
#
# Company Directory
#
#
# Check Trades/ Bids
#
#
# Exit Option for shareholders
#
#
# Regulatory Actions
#
#
#
#
# Making a Complaint
#
#
# Process
#
#
# File a Complaint Online
#
#
# Download Complaint Form
#
#
# Committees/ Panels
#
#
# Arbitration
#
#
# Defaulter / Expelled Members
#
#
#
#
#
#
#
#
#
#
#
#
# Investor's Home
# Investor education on how to invest safely and protect your investments.
#
#
#
#
#
#
#
#
#
# Product Information
# Browse NSE products under Cash, derivatives, currency derivatives etc.
#
#
#
#
#
#
#
#
#
# Login to NSE NICE Plus
# File and Track your Complaint online.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Investor's Home
# Investor education on how to invest safely and protect your investments.
#
#
#
#
#
#
#
#
#
# Product Information
# Browse NSE products under Cash, derivatives, currency derivatives etc.
#
#
#
#
#
#
#
#
#
# Login to NSE NICE Plus
# File and Track your Complaint online.
#
#
#
#
#
#
#
#
#
#
#
#
# Investor's Home
# Investor education on how to invest safely and protect your investments.
#
#
#
#
#
#
#
#
#
# Product Information
# Browse NSE products under Cash, derivatives, currency derivatives etc.
#
#
#
#
#
#
#
#
#
# Login to NSE NICE Plus
# File and Track your Complaint online.
#
#
#
#
#
#
#
#
#
#
# Investor's Home
# Investor education on how to invest safely and protect your investments.
#
#
#
#
#
#
#
#
# Investor's Home
# Investor education on how to invest safely and protect your investments.
#
#
#
#
#
#
#
#
# Product Information
# Browse NSE products under Cash, derivatives, currency derivatives etc.
#
#
#
#
#
#
#
#
# Product Information
# Browse NSE products under Cash, derivatives, currency derivatives etc.
#
#
#
#
#
#
#
#
# Login to NSE NICE Plus
# File and Track your Complaint online.
#
#
#
#
#
#
#
#
# Login to NSE NICE Plus
# File and Track your Complaint online.
#
#
#
#
#
#
# Raising Capital
#
#
# On-boarding Process
#
#
# Primary Market - Main Board
#
#
# Primary Market - SME
#
#
# Debt - Private Placement
#
#
# Mutual Fund/ETFs
#
#
# Further Issues
#
#
#
#
# Corporate Filings
#
#
# Announcements
#
#
# Board Meetings
#
#
# Corporate Actions
#
#
# Financial Results
#
#
# Shareholding Pattern
#
#
# Offer Documents
#
#
# Scheme of Arrangement
#
#
#
#
# Resources for Listed Companies
#
#
# SEBI Regulations
#
#
# Compliance Information
#
#
# XBRL Information
#
#
# Company Directory
#
#
# Circulars to Listed Companies
#
#
# Social Stock Exchange
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Corporates Home
# Important information, reference material and latest announcements for corporates
#
#
#
#
#
#
#
#
#
# Company Compliance Information
# Status of compliance's under various Regulatory requirements
#
#
#
#
#
#
#
#
#
# NEAPS Portal
# Login for Listed Companies
#
#
#
#
#
#
#
#
#
#
# Raising Capital
#
#
# On-boarding Process
#
#
# Primary Market - Main Board
#
#
# Primary Market - SME
#
#
# Debt - Private Placement
#
#
# Mutual Fund/ETFs
#
#
# Further Issues
#
#
#
#
# Corporate Filings
#
#
# Announcements
#
#
# Board Meetings
#
#
# Corporate Actions
#
#
# Financial Results
#
#
# Shareholding Pattern
#
#
# Offer Documents
#
#
# Scheme of Arrangement
#
#
#
#
# Resources for Listed Companies
#
#
# SEBI Regulations
#
#
# Compliance Information
#
#
# XBRL Information
#
#
# Company Directory
#
#
# Circulars to Listed Companies
#
#
# Social Stock Exchange
#
#
#
#
#
#
#
# Raising Capital
#
#
# On-boarding Process
#
#
# Primary Market - Main Board
#
#
# Primary Market - SME
#
#
# Debt - Private Placement
#
#
# Mutual Fund/ETFs
#
#
# Further Issues
#
#
#
#
# Corporate Filings
#
#
# Announcements
#
#
# Board Meetings
#
#
# Corporate Actions
#
#
# Financial Results
#
#
# Shareholding Pattern
#
#
# Offer Documents
#
#
# Scheme of Arrangement
#
#
#
#
# Resources for Listed Companies
#
#
# SEBI Regulations
#
#
# Compliance Information
#
#
# XBRL Information
#
#
# Company Directory
#
#
# Circulars to Listed Companies
#
#
# Social Stock Exchange
#
#
#
#
#
# Raising Capital
#
#
# On-boarding Process
#
#
# Primary Market - Main Board
#
#
# Primary Market - SME
#
#
# Debt - Private Placement
#
#
# Mutual Fund/ETFs
#
#
# Further Issues
#
#
#
#
# Corporate Filings
#
#
# Announcements
#
#
# Board Meetings
#
#
# Corporate Actions
#
#
# Financial Results
#
#
# Shareholding Pattern
#
#
# Offer Documents
#
#
# Scheme of Arrangement
#
#
#
#
# Resources for Listed Companies
#
#
# SEBI Regulations
#
#
# Compliance Information
#
#
# XBRL Information
#
#
# Company Directory
#
#
# Circulars to Listed Companies
#
#
# Social Stock Exchange
#
#
#
#
#
#
#
#
#
#
#
#
# Corporates Home
# Important information, reference material and latest announcements for corporates
#
#
#
#
#
#
#
#
#
# Company Compliance Information
# Status of compliance's under various Regulatory requirements
#
#
#
#
#
#
#
#
#
# NEAPS Portal
# Login for Listed Companies
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Corporates Home
# Important information, reference material and latest announcements for corporates
#
#
#
#
#
#
#
#
#
# Company Compliance Information
# Status of compliance's under various Regulatory requirements
#
#
#
#
#
#
#
#
#
# NEAPS Portal
# Login for Listed Companies
#
#
#
#
#
#
#
#
#
#
#
#
# Corporates Home
# Important information, reference material and latest announcements for corporates
#
#
#
#
#
#
#
#
#
# Company Compliance Information
# Status of compliance's under various Regulatory requirements
#
#
#
#
#
#
#
#
#
# NEAPS Portal
# Login for Listed Companies
#
#
#
#
#
#
#
#
#
#
# Corporates Home
# Important information, reference material and latest announcements for corporates
#
#
#
#
#
#
#
#
# Corporates Home
# Important information, reference material and latest announcements for corporates
#
#
#
#
#
#
#
#
# Company Compliance Information
# Status of compliance's under various Regulatory requirements
#
#
#
#
#
#
#
#
# Company Compliance Information
# Status of compliance's under various Regulatory requirements
#
#
#
#
#
#
#
#
# NEAPS Portal
# Login for Listed Companies
#
#
#
#
#
#
#
#
# NEAPS Portal
# Login for Listed Companies
#
#
#
#
#
#
# Become a Member
#
#
# Process & FAQs
#
#
# Eligibility Criteria & Categories
#
#
# Fees, Deposits & Networth
#
#
# Using ENIT
#
#
#
#
# Resources for Members
#
#
# Change In Membership
#
#
# Member Compliance
#
#
# Disciplinary Action
#
#
# Format
#
#
#
#
# Platforms & Services
#
#
# NSE Trading Technology
#
#
# NEAT & Non-NEAT Front end
#
#
# Test Market Facility
#
#
# Connectivity & User Id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Member's Home
# Important Information, reference materials and latest announcements for members.
#
#
#
#
#
#
#
#
#
# Member Portal
# ENIT - A Portal for Trading Members of NSE to manage their Membership and Compliance requirements.
#
#
#
#
#
#
#
#
#
# Exchange Communication
# Browse Exchange circulars, press release and media articles.
#
#
#
#
#
#
#
#
#
#
# Become a Member
#
#
# Process & FAQs
#
#
# Eligibility Criteria & Categories
#
#
# Fees, Deposits & Networth
#
#
# Using ENIT
#
#
#
#
# Resources for Members
#
#
# Change In Membership
#
#
# Member Compliance
#
#
# Disciplinary Action
#
#
# Format
#
#
#
#
# Platforms & Services
#
#
# NSE Trading Technology
#
#
# NEAT & Non-NEAT Front end
#
#
# Test Market Facility
#
#
# Connectivity & User Id
#
#
#
#
#
#
#
# Become a Member
#
#
# Process & FAQs
#
#
# Eligibility Criteria & Categories
#
#
# Fees, Deposits & Networth
#
#
# Using ENIT
#
#
#
#
# Resources for Members
#
#
# Change In Membership
#
#
# Member Compliance
#
#
# Disciplinary Action
#
#
# Format
#
#
#
#
# Platforms & Services
#
#
# NSE Trading Technology
#
#
# NEAT & Non-NEAT Front end
#
#
# Test Market Facility
#
#
# Connectivity & User Id
#
#
#
#
#
# Become a Member
#
#
# Process & FAQs
#
#
# Eligibility Criteria & Categories
#
#
# Fees, Deposits & Networth
#
#
# Using ENIT
#
#
#
#
# Resources for Members
#
#
# Change In Membership
#
#
# Member Compliance
#
#
# Disciplinary Action
#
#
# Format
#
#
#
#
# Platforms & Services
#
#
# NSE Trading Technology
#
#
# NEAT & Non-NEAT Front end
#
#
# Test Market Facility
#
#
# Connectivity & User Id
#
#
#
#
#
#
#
#
#
#
#
#
# Member's Home
# Important Information, reference materials and latest announcements for members.
#
#
#
#
#
#
#
#
#
# Member Portal
# ENIT - A Portal for Trading Members of NSE to manage their Membership and Compliance requirements.
#
#
#
#
#
#
#
#
#
# Exchange Communication
# Browse Exchange circulars, press release and media articles.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Member's Home
# Important Information, reference materials and latest announcements for members.
#
#
#
#
#
#
#
#
#
# Member Portal
# ENIT - A Portal for Trading Members of NSE to manage their Membership and Compliance requirements.
#
#
#
#
#
#
#
#
#
# Exchange Communication
# Browse Exchange circulars, press release and media articles.
#
#
#
#
#
#
#
#
#
#
#
#
# Member's Home
# Important Information, reference materials and latest announcements for members.
#
#
#
#
#
#
#
#
#
# Member Portal
# ENIT - A Portal for Trading Members of NSE to manage their Membership and Compliance requirements.
#
#
#
#
#
#
#
#
#
# Exchange Communication
# Browse Exchange circulars, press release and media articles.
#
#
#
#
#
#
#
#
#
#
# Member's Home
# Important Information, reference materials and latest announcements for members.
#
#
#
#
#
#
#
#
# Member's Home
# Important Information, reference materials and latest announcements for members.
#
#
#
#
#
#
#
#
# Member Portal
# ENIT - A Portal for Trading Members of NSE to manage their Membership and Compliance requirements.
#
#
#
#
#
#
#
#
# Member Portal
# ENIT - A Portal for Trading Members of NSE to manage their Membership and Compliance requirements.
#
#
#
#
#
#
#
#
# Exchange Communication
# Browse Exchange circulars, press release and media articles.
#
#
#
#
#
#
#
#
# Exchange Communication
# Browse Exchange circulars, press release and media articles.
#
#
#
#
#
#
# Exchange
#
#
# Market Rules & Regulations
#
#
# Market Surveillance
#
#
# Exchange Disclosures
#
#
# Defaulting Clients
#
#
# Investor's Beware
#
#
# Submit a Tip-Off
#
#
#
#
# Member
#
#
# Member Compliance
#
#
# Complaint against Members
#
#
# Action against Members
#
#
# Debarred Entities
#
#
# Circulars for Members
#
#
# Public Notice
#
#
#
#
# Corporates
#
#
# Company Compliance
#
#
# Rumour Verification
#
#
# Delisting of Companies
#
#
# Queries raised to Listed Companies
#
#
# Complaint Status against Companies
#
#
# Public Notice
#
#
#
#
#
#
#
#
#
# Exchange
#
#
# Market Rules & Regulations
#
#
# Market Surveillance
#
#
# Exchange Disclosures
#
#
# Defaulting Clients
#
#
# Investor's Beware
#
#
# Submit a Tip-Off
#
#
#
#
# Member
#
#
# Member Compliance
#
#
# Complaint against Members
#
#
# Action against Members
#
#
# Debarred Entities
#
#
# Circulars for Members
#
#
# Public Notice
#
#
#
#
# Corporates
#
#
# Company Compliance
#
#
# Rumour Verification
#
#
# Delisting of Companies
#
#
# Queries raised to Listed Companies
#
#
# Complaint Status against Companies
#
#
# Public Notice
#
#
#
#
#
#
#
# Exchange
#
#
# Market Rules & Regulations
#
#
# Market Surveillance
#
#
# Exchange Disclosures
#
#
# Defaulting Clients
#
#
# Investor's Beware
#
#
# Submit a Tip-Off
#
#
#
#
# Member
#
#
# Member Compliance
#
#
# Complaint against Members
#
#
# ...
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
#
#
# Members Message Area
#
#
#  Exchange has published Member Help Guide and new FAQs for Access to Markets. Visit the link: https://www.nseindia.com/trade/all-member-faqs
#
#
#
#
# Contact for Support
#
#
#                                             - Trade Support Toll Free no : 1800 266 0050 (Select IVR option 1)
#                                             Charged no : 022 68645400/ 022 50998100  (Select IVR option 1)
#                                             Timings : 8:00 AM to 2:00 AM on subsequent day (Monday to Friday)
#
#
#                                                 - Member Compliance Support Toll Free no : 1800 266 0050 (Select IVR option 3)
#                                                 Charged no : 022 68645400/ 022 50998100  (Select IVR option 3)
#                                                 Timings : 9:30 AM to 5:45 PM (Monday to Friday)
#
#
#
#
#
#
#
#
#
#
#
#
# Quick Links for Members
#
#
#
#
# Quick Links for Members
#
#
#
#
#
#
#
#
#
#
# Latest Circulars
# Trading
# Clearing
# Listing
# Compliance
# Others
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
#
#
# Members Message Area
#
#
#  Exchange has published Member Help Guide and new FAQs for Access to Markets. Visit the link: https://www.nseindia.com/trade/all-member-faqs
#
#
#
#
# Contact for Support
#
#
#                                             - Trade Support Toll Free no : 1800 266 0050 (Select IVR option 1)
#                                             Charged no : 022 68645400/ 022 50998100  (Select IVR option 1)
#                                             Timings : 8:00 AM to 2:00 AM on subsequent day (Monday to Friday)
#
#
#                                                 - Member Compliance Support Toll Free no : 1800 266 0050 (Select IVR option 3)
#                                                 Charged no : 022 68645400/ 022 50998100  (Select IVR option 3)
#                                                 Timings : 9:30 AM to 5:45 PM (Monday to Friday)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Latest Circulars
# Trading
# Clearing
# Listing
# Compliance
# Others
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
#
#
# Members Message Area
#
#
#  Exchange has published Member Help Guide and new FAQs for Access to Markets. Visit the link: https://www.nseindia.com/trade/all-member-faqs
#
#
#
#
# Contact for Support
#
#
#                                             - Trade Support Toll Free no : 1800 266 0050 (Select IVR option 1)
#                                             Charged no : 022 68645400/ 022 50998100  (Select IVR option 1)
#                                             Timings : 8:00 AM to 2:00 AM on subsequent day (Monday to Friday)
#
#
#                                                 - Member Compliance Support Toll Free no : 1800 266 0050 (Select IVR option 3)
#                                                 Charged no : 022 68645400/ 022 50998100  (Select IVR option 3)
#                                                 Timings : 9:30 AM to 5:45 PM (Monday to Friday)
#
#
#
#
#
#
#
#
#
#
#
#
# Latest Circulars
# Trading
# Clearing
# Listing
# Compliance
# Others
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
#
#
# Members Message Area
#
#
#  Exchange has published Member Help Guide and new FAQs for Access to Markets. Visit the link: https://www.nseindia.com/trade/all-member-faqs
#
#
#
#
# Contact for Support
#
#
#                                             - Trade Support Toll Free no : 1800 266 0050 (Select IVR option 1)
#                                             Charged no : 022 68645400/ 022 50998100  (Select IVR option 1)
#                                             Timings : 8:00 AM to 2:00 AM on subsequent day (Monday to Friday)
#
#
#                                                 - Member Compliance Support Toll Free no : 1800 266 0050 (Select IVR option 3)
#                                                 Charged no : 022 68645400/ 022 50998100  (Select IVR option 3)
#                                                 Timings : 9:30 AM to 5:45 PM (Monday to Friday)
#
#
#
#
#
#
#
#
#
#
# Latest Circulars
# Trading
# Clearing
# Listing
# Compliance
# Others
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
# Select All
#
#
#
#  Download
#
#
# View All Circulars
#
#
#
#
#
#
#
# Subscribe to RSS Feed
#
#
#
# Subscribe to RSS Feed
#
#
#
#
#
# Members Message Area
#
#
#  Exchange has published Member Help Guide and new FAQs for Access to Markets. Visit the link: https://www.nseindia.com/trade/all-member-faqs
#
#
#
#
# Contact for Support
#
#
#                                             - Trade Support Toll Free no : 1800 266 0050 (Select IVR option 1)
#                                             Charged no : 022 68645400/ 022 50998100  (Select IVR option 1)
#                                             Timings : 8:00 AM to 2:00 AM on subsequent day (Monday to Friday)
#
#
#                                                 - Member Compliance Support Toll Free no : 1800 266 0050 (Select IVR option 3)
#                                                 Charged no : 022 68645400/ 022 50998100  (Select IVR option 3)
#                                                 Timings : 9:30 AM to 5:45 PM (Monday to Friday)
#
#
#
#
#
#
#
#
# Members Message Area
#
#
#  Exchange has published Member Help Guide and new FAQs for Access to Markets. Visit the link: https://www.nseindia.com/trade/all-member-faqs
#
#
#
#
# Contact for Support
#
#
#                                             - Trade Support Toll Free no : 1800 266 0050 (Select IVR option 1)
#                                             Charged no : 022 68645400/ 022 50998100  (Select IVR option 1)
#                                             Timings : 8:00 AM to 2:00 AM on subsequent day (Monday to Friday)
#
#
#                                                 - Member Compliance Support Toll Free no : 1800 266 0050 (Select IVR option 3)
#                                                 Charged no : 022 68645400/ 022 50998100  (Select IVR option 3)
#                                                 Timings : 9:30 AM to 5:45 PM (Monday to Friday)
#
#
#
#
#
#
# Members Message Area
#
#
#  Exchange has published Member Help Guide and new FAQs for Access to Markets. Visit the link: https://www.nseindia.com/trade/all-member-faqs
#
#
#
# Members Message Area
#
#
#  Exchange has published Member Help Guide and new FAQs for Access to Markets. Visit the link: https://www.nseindia.com/trade/all-member-faqs
#
#
#
# Contact for Support
#
#
#                                             - Trade Support Toll Free no : 1800 266 0050 (Select IVR option 1)
#                                             Charged no : 022 68645400/ 022 50998100  (Select IVR option 1)
#                                             Timings : 8:00 AM to 2:00 AM on subsequent day (Monday to Friday)
#
#
#                                                 - Member Compliance Support Toll Free no : 1800 266 0050 (Select IVR option 3)
#                                                 Charged no : 022 68645400/ 022 50998100  (Select IVR option 3)
#                                                 Timings : 9:30 AM to 5:45 PM (Monday to Friday)
#
#
#
#
# Contact for Support
#
#
#                                             - Trade Support Toll Free no : 1800 266 0050 (Select IVR option 1)
#                                             Charged no : 022 68645400/ 022 50998100  (Select IVR option 1)
#                                             Timings : 8:00 AM to 2:00 AM on subsequent day (Monday to Friday)
#
#
#                                                 - Member Compliance Support Toll Free no : 1800 266 0050 (Select IVR option 3)
#                                                 Charged no : 022 68645400/ 022 50998100  (Select IVR option 3)
#                                                 Timings : 9:30 AM to 5:45 PM (Monday to Friday)
